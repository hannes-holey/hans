# %% [markdown]
# Cavitation Examples

# %%
import numpy as np
from pathlib import Path
from GaPFlow.problem import Problem
from utils.plotting import plot_overview_1d, plot_overview_2d, plot_midsection_2d
from utils.topography import (
    regen_conv_slider_pocket_1d,
    regen_conv_slider_pocket_2d,
    regen_twin_parabolic_slider,
    regen_twin_parabolic_slider_id,
)

DATA_DIR = Path('../../tests/data')

# %% [markdown]
# ---
# ## Convergent slider with pocket — 1D
#
# Linear converging wedge (1.1→1.0 µm) with a 0.4 µm rectangular pocket at x∈[4,10] mm.
# Periodic in y (effectively 1D). Dirichlet p=1e5 Pa at inlet and outlet.
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# <img src="./figures/Geometry_ConvSliderPocket.png"
#      alt="Conv. slider with pocket geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_1D.yaml)**

# %%
problem_1d = Problem.from_yaml('../../tests/configs/conv_slider_pocket_1D.yaml')
regen_conv_slider_pocket_1d(problem_1d, Nx_geo=50)
problem_1d.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_1D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_1D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 400
#   - Lx                       : 0.02
#   - dx                       : 5e-05
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 50
#   - dt                       : 1.0
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 10620000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - piezo:
#     - name                   : Barus
#     - aB                     : 1.2e-08
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.05
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 2294249.3339379854
#
# Jacobian block norms (unscaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       8.27e+01   0.00e+00   2.66e-02   3.44e+04   0.00e+00
#   momentum_y       0.00e+00   8.27e+01   1.33e-03   0.00e+00   0.00e+00
#   mass             5.05e+05   2.53e+04   3.33e-02   4.15e+08   5.77e-07
#   fb               0.00e+00   0.00e+00   0.00e+00   1.08e-06   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   1.77e+08   1.08e-06
#
# Jacobian block norms (scaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       3.47e-01   0.00e+00   1.00e+00   1.77e-01   0.00e+00
#   momentum_y       0.00e+00   1.00e+00   2.20e-01   0.00e+00   0.00e+00
#   mass             9.93e-01   3.26e-02   5.86e-04   1.00e+00   2.22e-01
#   fb               0.00e+00   0.00e+00   0.00e+00   9.68e-01   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   9.99e-01   9.76e-01
#
#   Characteristic scales: jx=2.50e+01  jy=3.80e+01  p=2.79e-03  theta=2.04e+04  xi=1.27e-10  R_momentum_x=9.55e+00  R_momentum_y=2.17e+00  R_mass=2.04e+04  R_fb=5.48e-11  R_R_oss=8.69e+03
#   R_scaled=3.020017e+02
# 2179480.6459925612
#   R_scaled=2.864758e+02
# 7159924.756172966
#   R_scaled=7.121668e+02
# 6687778.930889573
#   R_scaled=6.603496e+02
# 6191612.114811783
#   R_scaled=6.099549e+02
# 5741434.501709782
#   R_scaled=5.644428e+02
# 5333568.636506627
#   R_scaled=5.229829e+02
# 4960185.19714274
#   R_scaled=4.852761e+02
# 4621459.355509854
#   R_scaled=4.505528e+02
# 4317574.0189746
#   R_scaled=4.189316e+02
# 4185348.3388440018
#   R_scaled=3.994817e+02
# 4012872.347151852
#   R_scaled=3.803635e+02
# 3770021.3651400497
#   R_scaled=3.545737e+02
# 3524510.6371701215
#   R_scaled=3.297880e+02
# 3372691.5093144886
#   R_scaled=3.209964e+02
# 3188092.558587591
#   R_scaled=3.027396e+02
# 3011575.097923312
#   R_scaled=2.852357e+02
# 2845204.029202291
#   R_scaled=2.684696e+02
# 2690182.5170946927
#   R_scaled=2.528714e+02
# 2544793.481151565
#   R_scaled=2.382483e+02
# 2407504.0498511884
#   R_scaled=2.243105e+02
# 2277234.5360998893
#   R_scaled=2.107104e+02
# 2111017.965832208
#   R_scaled=1.997195e+02
# 1983067.2613768927
#   R_scaled=1.932272e+02
# 1881587.6406566352
#   R_scaled=1.869613e+02
# 1787959.4336864469
#   R_scaled=1.787267e+02
# 1699531.5037894393
#   R_scaled=1.692628e+02
# 1615269.6493825982
#   R_scaled=1.600095e+02
# 1534459.9312004
#   R_scaled=1.511435e+02
# 1456720.5080691064
#   R_scaled=1.421894e+02
# 1381645.3551021134
#   R_scaled=1.341577e+02
# 1329615.167428506
#   R_scaled=1.356918e+02
# 1328800.0333111524
#   R_scaled=1.415718e+02
# 1318922.9616482225
#   R_scaled=1.454100e+02
# 1284097.4587070947
#   R_scaled=1.448563e+02
# 1234998.699431308
#   R_scaled=1.407203e+02
# 1186760.3660059469
#   R_scaled=1.347405e+02
# 1138574.4104763449
#   R_scaled=1.280021e+02
# 1090058.288498341
#   R_scaled=1.215193e+02
# 1041085.4484376772
#   R_scaled=1.151776e+02
# 991728.7601213827
#   R_scaled=1.087883e+02
# 942261.4115116119
#   R_scaled=1.020648e+02
# 893315.2700701442
#   R_scaled=9.649340e+01
# 833572.5260968693
#   R_scaled=9.468336e+01
# 739810.3274402282
#   R_scaled=9.934988e+01
# 698670.5887470803
#   R_scaled=1.050911e+02
# 678305.6132575179
#   R_scaled=1.092528e+02
# 661909.6678337852
#   R_scaled=1.111458e+02
# 644170.5580431026
#   R_scaled=1.109885e+02
# 624140.718675437
#   R_scaled=1.091761e+02
# 10     1.0000e+00   1.0000e+01   5      1.0106e+00   9.1457e-12
# 602271.6125573288
#   R_scaled=1.061017e+02
# 580795.5966654936
#   R_scaled=1.023371e+02
# 559560.5636992165
#   R_scaled=9.802899e+01
# 538497.3784779556
#   R_scaled=9.331538e+01
# 517582.4263545754
#   R_scaled=8.879181e+01
# 496822.4675459643
#   R_scaled=8.447089e+01
# 476248.97394616244
#   R_scaled=8.033669e+01
# 455894.726640395
#   R_scaled=7.637522e+01
# 435808.6948954371
#   R_scaled=7.257317e+01
# 416044.60652133473
#   R_scaled=6.891734e+01
# 396658.7745482596
#   R_scaled=6.539385e+01
# 377708.53436427005
#   R_scaled=6.198689e+01
# 359253.0066897371
#   R_scaled=5.868275e+01
# 341356.6041401322
#   R_scaled=5.547453e+01
# 324088.5313824489
#   R_scaled=5.307746e+01
# 307521.59539638116
#   R_scaled=5.162083e+01
# 291719.06231514545
#   R_scaled=5.075132e+01
# 265342.11068845
#   R_scaled=5.129271e+01
# 240098.0864020235
#   R_scaled=5.424773e+01
# 243699.73317673575
#   R_scaled=5.793199e+01
# 267706.39411376335
#   R_scaled=6.196308e+01
# 302114.9223727206
#   R_scaled=6.608244e+01
# 339989.9142089027
#   R_scaled=7.010593e+01
# 377645.9011012238
#   R_scaled=7.392783e+01
# 413328.6162960265
#   R_scaled=7.749026e+01
# 446299.4643276868
#   R_scaled=8.076738e+01
# 476375.3622094708
#   R_scaled=8.375993e+01
# 503548.6837505973
#   R_scaled=8.646897e+01
# 527985.7698827055
#   R_scaled=8.891007e+01
# 549906.783325824
#   R_scaled=9.110268e+01
# 569547.2962507344
#   R_scaled=9.306785e+01
# 587154.3032386744
#   R_scaled=9.482975e+01
# 602897.4713351012
#   R_scaled=9.640596e+01
# 616884.4204963153
#   R_scaled=9.781745e+01
# 629414.5628863059
#   R_scaled=9.907645e+01
# 640647.5332552543
#   R_scaled=1.001994e+02
# 650730.8153983031
#   R_scaled=1.012027e+02
# 659780.8028007915
#   R_scaled=1.020977e+02
# 667908.1730536177
#   R_scaled=1.028960e+02
# 675210.6384387745
#   R_scaled=1.036084e+02
# 681774.548425997
#   R_scaled=1.042440e+02
# 687678.035451759
#   R_scaled=1.048120e+02
# 692985.9390161482
#   R_scaled=1.053189e+02
# 697758.6059376594
#   R_scaled=1.057711e+02
# 702049.715949273
#   R_scaled=1.061746e+02
# 705907.1085133795
#   R_scaled=1.065346e+02
# 709373.3107666387
#   R_scaled=1.068560e+02
# 712486.1128585943
#   R_scaled=1.071425e+02
# 715279.8401876097
#   R_scaled=1.073979e+02
# 717785.2900378085
#   R_scaled=1.076254e+02
# 20     1.0000e+00   2.0000e+01   5      1.1151e+00   7.2249e-13
# 720030.1359119688
#   R_scaled=1.078279e+02
# 722038.4952842429
#   R_scaled=1.080084e+02
# 723833.2557958242
#   R_scaled=1.081688e+02
# 725434.6161000711
#   R_scaled=1.083114e+02
# 726860.9143448444
#   R_scaled=1.084379e+02
# 728128.7252049173
#   R_scaled=1.085500e+02
# 729251.871145274
#   R_scaled=1.086494e+02
# 730244.9421649871
#   R_scaled=1.087372e+02
# 731120.2689485713
#   R_scaled=1.088147e+02
# 731889.0312222007
#   R_scaled=1.088831e+02
# 732561.3716187852
#   R_scaled=1.089432e+02
# 733145.3399464886
#   R_scaled=1.089959e+02
# 733650.3754913235
#   R_scaled=1.090421e+02
# 734084.0914512916
#   R_scaled=1.090824e+02
# 734453.4069515391
#   R_scaled=1.091174e+02
# 734764.6123876588
#   R_scaled=1.091478e+02
# 735022.3879346354
#   R_scaled=1.091740e+02
# 735232.9398477061
#   R_scaled=1.091964e+02
# 735401.010595292
#   R_scaled=1.092155e+02
# 735530.9145361433
#   R_scaled=1.092317e+02
# 735626.5768231135
#   R_scaled=1.092453e+02
# 735690.6784929908
#   R_scaled=1.092565e+02
# 735727.3439425016
#   R_scaled=1.092657e+02
# 735739.5338720568
#   R_scaled=1.092730e+02
# 735729.9408874171
#   R_scaled=1.092788e+02
# 735701.0132753433
#   R_scaled=1.092831e+02
# 735654.2371964706
#   R_scaled=1.092861e+02
# 735592.3715387529
#   R_scaled=1.092881e+02
# 735517.2565711588
#   R_scaled=1.092891e+02
# 735430.5630470567
#   R_scaled=1.092892e+02
# 735333.8070140267
#   R_scaled=1.092886e+02
# 735227.7607691748
#   R_scaled=1.092874e+02
# 735114.2754117057
#   R_scaled=1.092856e+02
# 734994.4810157203
#   R_scaled=1.092834e+02
# 734869.3999098085
#   R_scaled=1.092807e+02
# 734739.9560398702
#   R_scaled=1.092778e+02
# 734606.498915017
#   R_scaled=1.092745e+02
# 734470.2701869217
#   R_scaled=1.092710e+02
# 734331.9481215331
#   R_scaled=1.092673e+02
# 734192.1424366755
#   R_scaled=1.092634e+02
# 734051.4002757802
#   R_scaled=1.092594e+02
# 733909.8100942086
#   R_scaled=1.092554e+02
# 733768.2142067619
#   R_scaled=1.092512e+02
# 733627.0087478262
#   R_scaled=1.092470e+02
# 733486.5410331046
#   R_scaled=1.092428e+02
# 733347.1187861423
#   R_scaled=1.092386e+02
# 733208.7080996681
#   R_scaled=1.092344e+02
# 733071.8587382439
#   R_scaled=1.092303e+02
# 732936.7799426324
#   R_scaled=1.092261e+02
# 732803.6536755563
#   R_scaled=1.092220e+02
# 30     1.0000e+00   3.0000e+01   5      1.1587e+00   5.6143e-14
# 732672.6370970391
#   R_scaled=1.092180e+02
# 732543.6242540409
#   R_scaled=1.092140e+02
# 732416.9747447995
#   R_scaled=1.092101e+02
# 732292.7844009232
#   R_scaled=1.092063e+02
# 732171.1322044169
#   R_scaled=1.092025e+02
# 732052.081893345
#   R_scaled=1.091988e+02
# 731935.4947323429
#   R_scaled=1.091952e+02
# 731821.6010896452
#   R_scaled=1.091917e+02
# 731710.4273983426
#   R_scaled=1.091883e+02
# 731601.9899872803
#   R_scaled=1.091850e+02
# 731496.2961105007
#   R_scaled=1.091817e+02
# 731393.1973301119
#   R_scaled=1.091786e+02
# 731292.8365352713
#   R_scaled=1.091755e+02
# 731195.1991825376
#   R_scaled=1.091725e+02
# 731100.264963861
#   R_scaled=1.091696e+02
# 731008.0084666063
#   R_scaled=1.091668e+02
# 730918.2846377055
#   R_scaled=1.091641e+02
# 730831.1775905057
#   R_scaled=1.091614e+02
# 730746.6500593633
#   R_scaled=1.091589e+02
# 730664.6617838647
#   R_scaled=1.091564e+02
# 730585.1699301635
#   R_scaled=1.091540e+02
# 730508.0397798495
#   R_scaled=1.091517e+02
# 730433.3164291405
#   R_scaled=1.091494e+02
# 730360.951486464
#   R_scaled=1.091473e+02
# 730290.8953126053
#   R_scaled=1.091452e+02
# 730223.097276985
#   R_scaled=1.091431e+02
# 730157.4362248975
#   R_scaled=1.091412e+02
# 730093.9318126795
#   R_scaled=1.091393e+02
# 730032.5317642
#   R_scaled=1.091375e+02
# 729973.1836205515
#   R_scaled=1.091357e+02
# 729915.8348967198
#   R_scaled=1.091340e+02
# 729860.3790076348
#   R_scaled=1.091323e+02
# 729806.8194724919
#   R_scaled=1.091308e+02
# 729755.1045049373
#   R_scaled=1.091292e+02
# 729705.182764866
#   R_scaled=1.091278e+02
# 729657.0034433503
#   R_scaled=1.091263e+02
# 729610.474252979
#   R_scaled=1.091250e+02
# 729565.588903305
#   R_scaled=1.091237e+02
# 729522.2986107934
#   R_scaled=1.091224e+02
# 729480.5553775238
#   R_scaled=1.091212e+02
# 729440.3120389312
#   R_scaled=1.091200e+02
# 729401.4896396444
#   R_scaled=1.091188e+02
# 729364.0763345902
#   R_scaled=1.091177e+02
# 729328.0276496027
#   R_scaled=1.091167e+02
# 729293.3000571145
#   R_scaled=1.091157e+02
# 729259.8509914613
#   R_scaled=1.091147e+02
# 729227.6135342978
#   R_scaled=1.091138e+02
# 729196.5731051072
#   R_scaled=1.091129e+02
# 729166.6900810914
#   R_scaled=1.091120e+02
# 729137.9258293331
#   R_scaled=1.091111e+02
# 40     1.0000e+00   4.0000e+01   5      1.1755e+00   4.3610e-15
# 729110.2427066963
#   R_scaled=1.091103e+02
# 729083.5844249998
#   R_scaled=1.091096e+02
# 729057.9354884257
#   R_scaled=1.091088e+02
# 729033.2611918317
#   R_scaled=1.091081e+02
# 729009.5277971278
#   R_scaled=1.091074e+02
# 728986.7025205424
#   R_scaled=1.091067e+02
# 728964.738306001
#   R_scaled=1.091061e+02
# 728943.6198825713
#   R_scaled=1.091055e+02
# 728923.3172503693
#   R_scaled=1.091049e+02
# 728903.8013112737
#   R_scaled=1.091043e+02
# 728885.0438514971
#   R_scaled=1.091038e+02
# 728867.0057389858
#   R_scaled=1.091033e+02
# 728849.6725974096
#   R_scaled=1.091028e+02
# 728833.0187644187
#   R_scaled=1.091023e+02
# 728817.0193949321
#   R_scaled=1.091018e+02
# 728801.650440878
#   R_scaled=1.091014e+02
# 728786.8795035352
#   R_scaled=1.091009e+02
# 728772.6934632463
#   R_scaled=1.091005e+02
# 728759.0705540973
#   R_scaled=1.091001e+02
# 728745.989733461
#   R_scaled=1.090997e+02
# 728733.4306657166
#   R_scaled=1.090994e+02
# 728721.366631235
#   R_scaled=1.090990e+02
# 728709.7859206268
#   R_scaled=1.090987e+02
# 728698.670201695
#   R_scaled=1.090984e+02
# 728688.001777888
#   R_scaled=1.090980e+02
# 728677.7635630481
#   R_scaled=1.090978e+02
# 728667.9335966157
#   R_scaled=1.090975e+02
# 728658.5016023627
#   R_scaled=1.090972e+02
# 728649.4522334014
#   R_scaled=1.090969e+02
# 728640.7706905358
#   R_scaled=1.090967e+02
# 728632.4427024582
#   R_scaled=1.090964e+02
# 728624.450272134
#   R_scaled=1.090962e+02
# 728616.7844989566
#   R_scaled=1.090960e+02
# 728609.4326020202
#   R_scaled=1.090958e+02
# 728602.3822665785
#   R_scaled=1.090955e+02
# 728595.6216310841
#   R_scaled=1.090953e+02
# 728589.1359854728
#   R_scaled=1.090952e+02
# 728582.9177030403
#   R_scaled=1.090950e+02
# 728576.9561850438
#   R_scaled=1.090948e+02
# 728571.2412320876
#   R_scaled=1.090946e+02
# 728565.7630237333
#   R_scaled=1.090945e+02
# 728560.5095671071
#   R_scaled=1.090943e+02
# 728555.474382144
#   R_scaled=1.090942e+02
# 728550.6487171886
#   R_scaled=1.090940e+02
# 728546.0241537355
#   R_scaled=1.090939e+02
# 728541.5925922106
#   R_scaled=1.090938e+02
# 728537.3442794804
#   R_scaled=1.090936e+02
# 728533.2737490097
#   R_scaled=1.090935e+02
# 728529.3737964829
#   R_scaled=1.090934e+02
# 728525.6374999967
#   R_scaled=1.090933e+02
# 50     1.0000e+00   5.0000e+01   5      1.1754e+00   3.3880e-16
# =================================
# Total walltime   :  0:00:59
# (0.85 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_1d,
    title='Conv. slider + pocket 1D (Bertocchi 2013)',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_1D.csv',
    ref_label='Bertocchi',
    ref_x_scale=0.020,
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)

# %% [markdown]
# ---
# ## Convergent slider with pocket — 2D
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_2D.yaml)**

# %%
problem_2d_pocket = Problem.from_yaml('../../tests/configs/conv_slider_pocket_2D.yaml')
regen_conv_slider_pocket_2d(problem_2d_pocket, Nx_geo=60, Ny_geo=60)
problem_2d_pocket.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_2D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 180
#   - Lx                       : 0.02
#   - dx                       : 0.00011111111111111112
#   - Ny                       : 60
#   - Ly                       : 0.01
#   - dy                       : 0.00016666666666666666
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 100000.0
#   - bc_yN_P_val              : 100000.0
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 12
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - piezo:
#     - name                   : Barus
#     - aB                     : 1.2e-08
#   - thinning:
#     - name                   : Eyring
#     - tauE                   : 5000000.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.15
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 384231.98129992356
# 326778.87449437915
# 739085.5671874374
# 705043.1892100386
# 618599.3038790914
# 540891.1998694078
# 463282.2635549788
# 391330.5857234902
# 332441.8794333416
# 282985.7675497355
# 245530.33550844638
# 209826.03832147975
# 180263.27087897062
# 157829.02054073437
# 139938.19836938436
# 124465.176748225
# 111139.39251779126
# 99647.90968319133
# 90240.22461701324
# 82388.20839821266
# 75789.58843789923
# 70375.29200579751
# 65984.93989025055
# 62608.57367320388
# 60160.04337828731
# 58519.65119716658
# 57522.744801719986
# 57013.73513433555
# 56854.18853948912
# 56920.79316916063
# 57131.068302787935
# 57422.24906277858
# 57754.53072699946
# 58098.73902538303
# 58435.83027152341
# 58754.66234879127
# 59049.48372040995
# 59317.62830094299
# 59558.4327982107
# 59772.14627425567
# 59960.92581945705
# 60126.59387309935
# 60271.39900881528
# 60397.488738074826
# 60506.944760540806
# 60601.72259767061
# 60683.55959412965
# 60754.153687049395
# 60814.963487813446
# 60867.283549490516
# 10     1.0000e-01   1.0000e+00   5      1.4936e+01   8.3470e-12
# 60912.25469251753
# 60950.84897448887
# 60983.97146421766
# 61012.381507967526
# 61036.73773263486
# 61057.60995739577
# 61075.47761714513
# 61090.77951662345
# 61103.88095614997
# 61115.0961295372
# =================================
# Total walltime   :  0:03:02
# (0.07 steps/s)
# =================================

# %%
plot_overview_2d(problem_2d_pocket, '2D Pocketed Convergent Slider')

# %%
plot_midsection_2d(
    problem_2d_pocket,
    title='2D Pocketed Convergent Slider - Midsection',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_2D.csv',
    ref_label='Bertocchi',
)

# %% [markdown]
# ---
# ## Parabolic slider — 1D
#
# <img src="./figures/Geometry_ParabolicSlider.png"
#      alt="Parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_slider.yaml)**

# %%
problem_par1d = Problem.from_yaml('../../tests/configs/parabolic_slider_cav.yaml')
problem_par1d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_slider.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_slider
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 256
#   - Lx                       : 0.0762
#   - dx                       : 0.00029765625
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 0.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 50
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.001
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - p_init                   : 103338.25
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=100000 Pa  min=100000  max=100000
#   BC pressure E: mean=7.0762e-06 Pa  min=7.0762e-06  max=7.0762e-06
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 62547209.11672937
#
# Jacobian block norms (unscaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       1.96e+00   0.00e+00   2.13e-02   3.84e+03   0.00e+00
#   momentum_y       0.00e+00   1.96e+00   6.34e-03   0.00e+00   0.00e+00
#   mass             3.70e+06   1.10e+06   3.49e-01   1.43e+10   2.75e-06
#   fb               0.00e+00   0.00e+00   0.00e+00   5.14e-06   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   6.11e+09   5.14e-06
#
# Jacobian block norms (scaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       1.52e-01   0.00e+00   9.95e-01   7.77e-02   0.00e+00
#   momentum_y       0.00e+00   9.93e-01   1.00e+00   0.00e+00   0.00e+00
#   mass             9.92e-01   5.73e-01   5.63e-05   1.00e+00   2.22e-01
#   fb               0.00e+00   0.00e+00   0.00e+00   9.66e-01   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   9.99e-01   9.74e-01
#
#   Characteristic scales: jx=3.11e+01  jy=1.61e+01  p=5.18e-02  theta=1.20e+05  xi=1.03e-10  R_momentum_x=4.14e-01  R_momentum_y=1.23e-01  R_mass=1.20e+05  R_fb=4.45e-11  R_R_oss=5.11e+04
#   R_scaled=8.967256e+02
# 56292320.26039914
#   R_scaled=7.982096e+02
# 159879160.95494166
#   R_scaled=1.995853e+03
# 158189077.58054185
#   R_scaled=1.996135e+03
# 155487086.5186226
#   R_scaled=1.972585e+03
# 139755879.87591693
#   R_scaled=1.775160e+03
# 124838443.91384292
#   R_scaled=1.610703e+03
# 114641141.45423101
#   R_scaled=1.481286e+03
# 112213324.93445586
#   R_scaled=1.738274e+03
# 101172409.17325586
#   R_scaled=1.583542e+03
# 10     1.0000e-01   1.0000e+00   1      1.3518e-01   5.4928e-10
# 89544864.25744271
#   R_scaled=1.404356e+03
# 79731849.15634361
#   R_scaled=1.251658e+03
# 71339704.835454
#   R_scaled=1.119947e+03
# 64073974.32936735
#   R_scaled=1.005179e+03
# 57715164.510943756
#   R_scaled=9.042966e+02
# 52099366.55895255
#   R_scaled=8.149723e+02
# 47103299.55183578
#   R_scaled=7.354215e+02
# 42633091.321718454
#   R_scaled=6.642558e+02
# 38616051.25291671
#   R_scaled=6.003754e+02
# 34994742.76969776
#   R_scaled=5.428916e+02
# 20     1.0000e-01   2.0000e+00   1      2.0408e-01   1.3779e-10
# 31722769.037570965
#   R_scaled=4.910714e+02
# 28761804.791471604
#   R_scaled=4.442988e+02
# 26079517.997510865
#   R_scaled=4.020465e+02
# 23648117.902453933
#   R_scaled=3.638569e+02
# 21443339.121007066
#   R_scaled=3.293277e+02
# 19443726.61736509
#   R_scaled=2.981022e+02
# 17630126.941330027
#   R_scaled=2.698614e+02
# 15985320.1781664
#   R_scaled=2.443192e+02
# 14493747.64875076
#   R_scaled=2.212175e+02
# 13141304.769143574
#   R_scaled=2.003233e+02
# 30     1.0000e-01   3.0000e+00   1      1.5038e-01   4.1457e-11
# 11915178.415527869
#   R_scaled=1.814257e+02
# 10803714.950038847
#   R_scaled=1.643340e+02
# 9796309.690883081
#   R_scaled=1.488753e+02
# 8883311.729570651
#   R_scaled=1.348931e+02
# 8055940.082909884
#   R_scaled=1.222457e+02
# 7306208.5473536495
#   R_scaled=1.108048e+02
# 6626857.527189794
#   R_scaled=1.004545e+02
# 6011291.692638582
#   R_scaled=9.108973e+01
# 5453522.696616494
#   R_scaled=8.261573e+01
# 4948116.412469898
#   R_scaled=7.494679e+01
# 40     1.0000e-01   4.0000e+00   1      1.3211e-01   1.3622e-11
# 4490144.298458911
#   R_scaled=6.800551e+01
# 4075138.5808965946
#   R_scaled=6.172200e+01
# 3699050.9984272057
#   R_scaled=5.603316e+01
# 3358214.8789640698
#   R_scaled=5.088206e+01
# 3049310.3375685923
#   R_scaled=4.621733e+01
# 2769332.3935757624
#   R_scaled=4.199261e+01
# 2515561.8123147627
#   R_scaled=3.816610e+01
# 2285538.4824572275
#   R_scaled=3.470007e+01
# 2077037.145878172
#   R_scaled=3.156050e+01
# 1888045.3031728885
#   R_scaled=2.871671e+01
# 50     1.0000e-01   5.0000e+00   1      1.2947e-01   4.6341e-12
# =================================
# Total walltime   :  0:00:08
# (5.97 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_par1d,
    title='Parabolic slider 1D',
    ref_csv=DATA_DIR / 'ref_parabolic_slider.csv',
    ref_label='Bayada',
    ref_x_scale=problem_par1d.grid['Lx'],
    ref_p_scale=1.0,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Parabolic slider — 2D
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_2D.yaml)**

# %%
problem_par2d = Problem.from_yaml('../../tests/configs/parabolic_2D.yaml')
problem_par2d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_2D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.0762
#   - dx                       : 0.00038100000000000005
#   - Ny                       : 200
#   - Ly                       : 0.0762
#   - dy                       : 0.00038100000000000005
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 101325.0
#   - bc_xE_P_val              : 101325.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 101325.0
#   - bc_yN_P_val              : 101325.0
# - geometry:
#   - U_bot                    : 0.7
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic_2d
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 1e-14
#   - max_it                   : 40
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.2
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 15646309.350059599
# 12517047.479872499
# 10013644.44568482
# 8010917.303602934
# 119960388.19129643
# 118518515.00942448
# 99953661.99337533
# 81571567.0385916
# 64501234.4003024
# 50449875.6953364
# 10     1.0000e-01   1.0000e+00   1      2.1265e+01   4.1099e-10
# 39540834.12566376
# 31275910.03036206
# 24798416.248388745
# 19751907.6631371
# 15791558.657619463
# 12667096.907604823
# 10262915.381590623
# 8424795.672250265
# 7018991.709763956
# 5963808.070255084
# 20     1.0000e-01   2.0000e+00   1      2.1920e+01   4.5883e-11
# 5202779.720271286
# 4682094.632733078
# 4342980.7924798755
# 4137996.790211573
# 4027340.4426412485
# 3980672.4543869556
# 3973785.0275455844
# 3991438.2315358534
# 4022354.0840771794
# 4059657.3962973054
# 30     1.0000e-01   3.0000e+00   1      2.1704e+01   4.9596e-12
# 4099452.7497518426
# 4138978.339609518
# 4176558.038169883
# 4211279.287103796
# 4242704.555653424
# 4270734.386851548
# 4295472.064002824
# 4317110.794290188
# 4335899.650059741
# 4352089.259553665
# 40     1.0000e-01   4.0000e+00   1      2.3564e+01   5.3224e-13
# =================================
# Total walltime   :  0:14:40
# (0.05 steps/s)
# =================================

# %%
plot_overview_2d(problem_par2d, 'Parabolic slider 2D')

# %% [markdown]
# ---
# ## Twin parabolic slider non-identical — 1D
#
# Two asymmetric parabolic sliders (hmin₁=30 µm, hmin₂=35 µm) with a flat separator and flat outlet region.
# Dirichlet ρ at ambient at both ends, periodic in y.
#
# **Reference:** Bayada et al. (Fig. 7).
#
# <img src="./figures/Geometry_TwinParabolicSlider.png"
#      alt="Twin parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider.yaml)**

# %%
problem_twin = Problem.from_yaml('../../tests/configs/twin_parabolic_slider.yaml')
regen_twin_parabolic_slider(problem_twin)
problem_twin.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider
#   - write_freq               : 100
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.09
#   - dx                       : 0.00045
#   - Ny                       : 2
#   - Ly                       : 0.004
#   - dy                       : 0.002
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_D_val              : 877.7008
#   - bc_xE_D_val              : 877.7008
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 2.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 6e-05
#   - hmin                     : 3e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 100
#   - dt                       : 0.08
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7008
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 20000.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver] Using reference pressure p_ref = 1.000e+05 Pa for scaling
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 87347538.9052102
# 78612891.1467116
# 1059263254.4753125
# 917465406.8059237
# 796020935.2022966
# 693959739.1314204
# 591012821.2422146
# 526688961.0297326
# 493499725.68777883
# 437048084.2644756
# 389556890.2165633
# 349079296.44833
# 314012374.69002223
# 284028746.71091694
# 258414492.0965739
# 236169001.49980816
# 216167193.31506228
# 198266193.0505798
# 182309980.54796475
# 168054639.27113548
# 155252384.75532794
# 143688876.81447405
# 133187859.14889768
# 123606236.00944224
# 114827638.41732782
# 106756696.00472224
# 99314451.11325225
# 92434835.56481473
# 86062001.13255721
# 80148294.89620055
# 74652708.25797895
# 69539670.02511169
# 64778090.384635665
# 60340591.755778946
# 56202883.905881114
# 52343254.69924653
# 48742155.883381814
# 45381547.42332022
# 42243368.50214323
# 39312976.979392044
# 36576959.920224346
# 34022953.67162767
# 31639502.194664016
# 29415945.821680736
# 27342333.62595801
# 25409353.757052533
# 23608277.255066957
# 21930911.900254067
# 20369563.52368478
# 18917002.888397653
# 17566436.76520651
# 16311482.202802492
# 15146143.259595817
# 14064789.652722634
# 13062136.910935428
# 12133227.69441393
# 11273438.908440722
# 10478422.328878915
# 9744079.925741956
# 9066578.171682453
# 8442330.966899097
# 7867982.8525315
# 7340392.363156918
# 6856615.408289999
# 6413888.624992943
# 6009612.708165893
# 5641335.81463133
# 5306737.23615777
# 5003611.643628023
# 4729854.313780211
# 4483447.8327540625
# 4262450.809281484
# 4064989.101768541
# 3889249.9529325445
# 3733479.2324836017
# 3595981.730989652
# 3475124.1634407085
# 3369340.277911599
# 3277137.271631048
# 3197102.628985532
# 3127910.52584028
# 3068327.0792497015
# 3017213.928445118
# 2973529.869981399
# 2936330.496892102
# 2904765.978899086
# 2878077.252209085
# 2855590.9606391788
# 2836713.5118100806
# 2820924.595272904
# 2807770.4673852483
# 2796857.2528202254
# 2787844.4543907847
# 2780438.8078725087
# 2774388.570495093
# 2769478.2923865276
# 2765524.0895969323
# 2762369.4147345154
# 2759881.305525786
# 2757947.0814258284
# 100    8.0000e-02   8.0000e+00   1      2.7607e-02   1.9176e-13
# =================================
# Total walltime   :  0:00:03
# (26.73 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin,
    title='Twin parabolic slider uneven',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider.csv',
    ref_label='Bayada',
    ref_x_scale=0.09,
    ref_p_scale=1e5,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Twin parabolic slider identical — 1D
#
# Two identical symmetric parabolic sliders (hmax=50.2 µm, hmin=25.4 µm).
# High inlet pressure p_in=3.36e5 Pa, p_out≈0 Pa, periodic in y.
#
# **Reference:** Sahlin et al. / Giacopini et al., J. Tribology 132 (2010), 041702.
#
# <img src="./figures/Geometry_TwinParabolicSliderIdentical.png"
#      alt="Twin identical parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider_id.yaml)**

# %%
problem_twin_id = Problem.from_yaml('../../tests/configs/twin_parabolic_slider_id.yaml')
regen_twin_parabolic_slider_id(problem_twin_id)
problem_twin_id.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider_id.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider_id
#   - write_freq               : 50
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.0762
#   - dx                       : 0.00038100000000000005
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['N', 'N', 'N']
#   - bc_xW_P_val              : 336414.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 5.02e-05
#   - hmin                     : 2.54e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 300
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 400.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.04
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver] Using reference pressure p_ref = 1.000e+05 Pa for scaling
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 3049177.452211727
# 2930126.0233964035
# 2847601.037548316
# 2767701.5159799578
# 2661252.882657285
# 2559120.954897749
# 2470524.984211622
# 5124951.831896382
# 7079580.85272293
# 6870625.076399649
# 5657132.043153835
# 7444729.127302634
# 5955538.753162797
# 6890990.484109348
# 5852574.276902814
# 6002696.26172683
# 6296316.28980149
# 5460062.369683711
# 6581570.07777521
# 5228645.512645364
# 6798967.47150108
# 5290705.548795726
# 6139246.166512993
# 4901742.45785949
# 5802602.679489213
# 4588612.286018074
# 5565764.154968987
# 4553235.99971557
# 5167528.364533728
# 4409817.530303965
# 4802406.418503951
# 4265832.433363757
# 4481924.810431145
# 4231966.684459141
# 4123955.14733019
# 4101804.4508432695
# 3803696.1648559114
# 3939698.1517274273
# 3445512.047619274
# 3909953.9483053754
# 2964656.676080624
# 3913409.297231195
# 2586130.6223543826
# 3791023.531774663
# 3113499.2314385353
# 3497643.4940186813
# 4071729.6306554293
# 2600742.930964616
# 3317363.902083508
# 3132608.0991837624
# 50     1.0000e-01   5.0000e+00   1      8.1815e-02   6.7662e-10
# 2693032.3493545684
# 3454796.3591587697
# 2570404.8115267367
# 2848462.863712535
# 3074658.957303825
# 2013776.701380049
# 2754915.3802727135
# 2760424.681213486
# 1796409.9109412883
# 2611858.072636337
# 2649723.506509111
# 1782914.0492178793
# 2339656.365738605
# 2532538.4957948164
# 1912351.3645227451
# 2055501.4123286759
# 2431026.0114586763
# 2422593.36068165
# 1569468.0847625295
# 1888051.5603743917
# 2135136.6905064583
# 2180860.649780176
# 1513868.849929518
# 1869224.4305696872
# 2190172.5031032064
# 1441286.025363027
# 3034660.0045883395
# 3403206.671403284
# 3394511.045389878
# 3054963.1158158006
# 2302959.967839467
# 2167176.6515626027
# 2190913.8272451656
# 2233579.108623804
# 2259044.7801066213
# 2257999.4284776472
# 2222539.2795337667
# 2020353.5100890498
# 1787077.9725071706
# 1767117.3273302536
# 1803799.2354738647
# 1843261.12485951
# 1864332.2912987403
# 1842129.362352515
# 1528353.5395102443
# 1531781.9751184592
# 1623609.9799529181
# 1675150.790384588
# 1717354.2294015156
# 1731763.4900001925
# 100    1.0000e-01   1.0000e+01   1      7.2536e-02   7.4266e-11
# 1701677.3730560157
# 1387306.68182891
# 1257109.7376282322
# 1249447.7183991696
# 1276785.2600133372
# 1302847.4633088775
# 1327114.8303380862
# 1348430.1953007132
# 1363201.3528823566
# 1368832.055065738
# 1362819.0529558188
# 1342237.0122075991
# 1303333.2070694019
# 1181999.3330438875
# 1015759.7997863243
# 926184.8225249359
# 890622.1462812556
# 887226.5114897514
# 899197.3576950628
# 915989.6139194902
# 931973.3564600634
# 944612.5236668158
# 956451.8838896453
# 966843.4049794223
# 975066.8131821569
# 980651.8601345514
# 983309.570646125
# 982824.7933473821
# 979039.0784681332
# 971827.1593653116
# 961092.3025889874
# 946768.2574528767
# 928793.8585426672
# 907037.3748373437
# 881280.5760320094
# 851503.5061128704
# 817249.6612250783
# 730062.4579307715
# 647908.4138979106
# 585974.015038121
# 543333.8875112431
# 518354.71940308803
# 508526.0625383316
# 510711.1331425602
# 521657.44323418784
# 538456.745995533
# 558777.0073514396
# 580885.610130611
# 603562.0912867226
# 625980.7590691926
# 150    1.0000e-01   1.5000e+01   1      7.6841e-02   1.4947e-11
# 647603.3647996113
# 668094.3583409307
# 687258.4942558956
# 704996.471369816
# 721273.9230780086
# 736099.8990198874
# 749511.9693245933
# 761565.9164453
# 772328.6016603694
# 781873.0334295403
# 790274.9686831346
# 797610.5858765182
# 803954.9103709464
# 809380.7696082373
# 813958.1221199591
# 817753.6504238265
# 820830.5398728314
# 823248.3879481696
# 825063.2043010925
# 826358.1503062346
# 827257.3659591811
# 827697.7035874858
# 827720.9345256379
# 827366.8292059764
# 826672.3383730392
# 825671.7501079816
# 824396.844893409
# 822877.0467472826
# 821139.5691153356
# 819209.5546930544
# 817110.2086979778
# 814862.925365452
# 812487.4076212859
# 810001.7800118859
# 807422.6950600743
# 804765.4332734996
# 802043.9970697544
# 799271.1989038552
# 796458.7438940634
# 793617.3072439196
# 790756.6067546998
# 787885.4707147004
# 785011.9014413687
# 782143.134740125
# 779285.6955306835
# 776445.449878177
# 773627.653652774
# 770836.9980281891
# 768077.6520165527
# 765353.302224657
# 200    1.0000e-01   2.0000e+01   1      7.1251e-02   1.6820e-12
# 762667.190004892
# 760022.1461629161
# 757420.6233738308
# 754864.7264486252
# 752356.2405836752
# 749896.6577174276
# 747487.2011106485
# 745128.8482590417
# 742822.3522404343
# 740568.2615922759
# 738366.9388092753
# 736218.5775457214
# 734123.218601756
# 732080.7647682867
# 730090.9946007888
# 728153.5751881804
# 726268.0739790907
# 724433.9697242819
# 722650.6625906916
# 720917.4834993295
# 719233.7027364087
# 717598.537884224
# 716011.1611157572
# 714470.7058944502
# 712976.2731182927
# 711526.9377504342
# 710121.905824779
# 708760.1182067113
# 707440.5741283275
# 706162.2822502108
# 704924.2461820262
# 703725.4676313997
# 702564.9492418079
# 701441.6971422038
# 700354.7232297964
# 699303.0472059797
# 698285.6983843734
# 697301.7172884807
# 696350.1570556758
# 695430.0846628761
# 694540.5819884781
# 693680.7467240436
# 692849.6931483895
# 692046.5527758817
# 691270.4748899044
# 690520.6269717118
# 689796.1950341933
# 689096.383869388
# 688420.4172178856
# 687767.5378678046
# 250    1.0000e-01   2.5000e+01   1      7.7497e-02   2.1493e-13
# 687137.0076902604
# 686528.1076179536
# 685940.1375727564
# 685372.4163479445
# 684824.2814501056
# 684295.0889054729
# 683784.2130349507
# 683291.0462018427
# 682814.9985358629
# 682355.4976368188
# 681911.9882608734
# 681483.9319923247
# 681070.8069032602
# 680672.1072034587
# 680287.3428826111
# 679916.0393466692
# 679557.7370501066
# 679211.9911255589
# 678878.371012184
# 678556.4600840634
# 678245.8552796297
# 677946.1667331536
# 677657.0174091454
# 677378.042740385
# 677108.8902702937
# 676849.2193002196
# 676598.7005420685
# 676357.0157768221
# 676123.8575191965
# 675898.9286888213
# 675681.9422881433
# 675472.6237424363
# 675270.7136560268
# 675075.9412332232
# 674888.0568170605
# 674706.8193230545
# 674531.9959609277
# 674363.3619636536
# 674200.7003238427
# 674043.8015373985
# 673892.4633544023
# 673746.4905371164
# 673605.6946250943
# 673469.8937071826
# 673338.9122004322
# 673212.5806356827
# 673090.7354497843
# 672973.2187842672
# 672859.8782903485
# 672750.5669401342
# 300    1.0000e-01   3.0000e+01   1      7.9650e-02   3.0054e-14
# =================================
# Total walltime   :  0:00:25
# (11.65 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin_id,
    title='Twin parabolic slider identical',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider_id.csv',
    ref_label='Sahlin',
    ref_x_scale=problem_twin_id.grid['Lx'],
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)
