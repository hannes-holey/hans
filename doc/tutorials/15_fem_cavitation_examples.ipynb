# %% [markdown]
# Cavitation Examples

# %%
import numpy as np
from pathlib import Path
from GaPFlow.problem import Problem
from utils.plotting import plot_overview_1d, plot_overview_2d, plot_midsection_2d
from utils.topography import (
    regen_conv_slider_pocket_1d,
    regen_conv_slider_pocket_2d,
    regen_twin_parabolic_slider,
    regen_twin_parabolic_slider_id,
)

DATA_DIR = Path('../../tests/ref_data')

# %% [markdown]
# ---
# ## Convergent slider with pocket — 1D
#
# Linear converging wedge (1.1→1.0 µm) with a 0.4 µm rectangular pocket at x∈[4,10] mm.
# Periodic in y (effectively 1D). Dirichlet p=1e5 Pa at inlet and outlet.
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# <img src="./figures/Geometry_ConvSliderPocket.png"
#      alt="Conv. slider with pocket geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_1D.yaml)**

# %%
problem_1d = Problem.from_yaml('../../tests/configs/conv_slider_pocket_1D.yaml')
regen_conv_slider_pocket_1d(problem_1d, Nx_geo=50)
problem_1d.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_1D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_1D
#   - write_freq               : 2
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.02
#   - dx                       : 0.0001
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 20
#   - dt                       : 1.0
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 10620000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - piezo:
#     - name                   : Barus
#     - aB                     : 1.2e-08
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.05
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.0
#     - oss_alpha              : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 2      1.0000e+00   2.0000e+00   5      3.7834e-01   1.3397e-10   2.6811e+06
# 4      1.0000e+00   4.0000e+00   5      4.0178e-01   8.5132e-11   1.7099e+06
# 6      1.0000e+00   6.0000e+00   5      3.7938e-01   5.3337e-11   1.0960e+06
# 8      1.0000e+00   8.0000e+00   5      3.7797e-01   3.1852e-11   7.7849e+05
# 10     1.0000e+00   1.0000e+01   5      3.7773e-01   2.0255e-11   5.5791e+05
# 12     1.0000e+00   1.2000e+01   5      3.7300e-01   1.1698e-11   5.0989e+05
# 14     1.0000e+00   1.4000e+01   5      3.9995e-01   7.0242e-12   5.4484e+05
# 16     1.0000e+00   1.6000e+01   5      3.7572e-01   4.2461e-12   5.4458e+05
# 18     1.0000e+00   1.8000e+01   5      3.7321e-01   2.5614e-12   5.3549e+05
# 20     1.0000e+00   2.0000e+01   5      3.7923e-01   1.5416e-12   5.2635e+05
# =================================
# Total walltime   :  0:00:08
# (2.30 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_1d,
    title='Conv. slider + pocket 1D (Bertocchi 2013)',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_1D.csv',
    ref_label='Bertocchi',
    ref_x_scale=0.020,
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)

# %% [markdown]
# ---
# ## Convergent slider with pocket — 2D
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_2D.yaml)**

# %%
problem_2d_pocket = Problem.from_yaml('../../tests/configs/conv_slider_pocket_2D.yaml')
regen_conv_slider_pocket_2d(problem_2d_pocket, Nx_geo=60, Ny_geo=60)
problem_2d_pocket.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_2D
#   - write_freq               : 1
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 120
#   - Lx                       : 0.02
#   - dx                       : 0.00016666666666666666
#   - Ny                       : 60
#   - Ly                       : 0.01
#   - dy                       : 0.00016666666666666666
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 100000.0
#   - bc_yN_P_val              : 100000.0
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 12
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - piezo:
#     - name                   : Barus
#     - aB                     : 1.2e-08
#   - thinning:
#     - name                   : Eyring
#     - tauE                   : 5000000.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.15
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.0
#     - oss_alpha              : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 1      1.0000e-01   1.0000e-01   5      1.2198e+01   2.6360e-08   4.1675e+05
# 2      1.0000e-01   2.0000e-01   5      8.4244e+00   8.3582e-09   1.9569e+05
# 3      1.0000e-01   3.0000e-01   5      8.6435e+00   3.6833e-09   1.0358e+05
# 4      1.0000e-01   4.0000e-01   5      8.2980e+00   1.6300e-09   6.2209e+04
# 5      1.0000e-01   5.0000e-01   5      1.1263e+01   7.3181e-10   6.3052e+04
# 6      1.0000e-01   6.0000e-01   5      8.2416e+00   3.2602e-10   6.8463e+04
# 7      1.0000e-01   7.0000e-01   5      8.5225e+00   1.4481e-10   7.1634e+04
# 8      1.0000e-01   8.0000e-01   5      1.1428e+01   6.4245e-11   7.3176e+04
# 9      1.0000e-01   9.0000e-01   5      8.5236e+00   2.8491e-11   7.3889e+04
# 10     1.0000e-01   1.0000e+00   5      8.3714e+00   1.2633e-11   7.4211e+04
# 11     1.0000e-01   1.1000e+00   5      8.3885e+00   5.6009e-12   7.4356e+04
# 12     1.0000e-01   1.2000e+00   5      8.3336e+00   2.4832e-12   7.4421e+04
# =================================
# Total walltime   :  0:01:51
# (0.11 steps/s)
# =================================

# %%
plot_overview_2d(problem_2d_pocket, '2D Pocketed Convergent Slider')

# %%
plot_midsection_2d(
    problem_2d_pocket,
    title='2D Pocketed Convergent Slider - Midsection',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_2D.csv',
    ref_label='Bertocchi',
)

# %% [markdown]
# ---
# ## Parabolic slider — 1D
#
# <img src="./figures/Geometry_ParabolicSlider.png"
#      alt="Parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_slider_cav.yaml)**

# %%
problem_par1d = Problem.from_yaml('../../tests/configs/parabolic_slider_cav.yaml')
problem_par1d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_slider_cav.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_slider
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 256
#   - Lx                       : 0.0762
#   - dx                       : 0.00029765625
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 0.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 50
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.001
#     - oss_alpha              : 1.0
#   - oss_correction_alpha     : 1.0
#   - p_init                   : 103338.25
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 10     1.0000e-01   1.0000e+00   1      1.2742e-01   4.4306e-10   1.3142e+08
# 20     1.0000e-01   2.0000e+00   1      1.2664e-01   1.1164e-10   5.0206e+07
# 30     1.0000e-01   3.0000e+00   1      1.3770e-01   3.2897e-11   2.8554e+07
# 40     1.0000e-01   4.0000e+00   1      1.1029e-01   1.0389e-11   1.4914e+07
# 50     1.0000e-01   5.0000e+00   1      1.2661e-01   3.3520e-12   7.1139e+06
# =================================
# Total walltime   :  0:00:07
# (6.33 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_par1d,
    title='Parabolic slider 1D',
    ref_csv=DATA_DIR / 'ref_parabolic_slider.csv',
    ref_label='Bayada',
    ref_x_scale=problem_par1d.grid['Lx'],
    ref_p_scale=1.0,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Parabolic slider — 2D
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_2D.yaml)**

# %%
problem_par2d = Problem.from_yaml('../../tests/configs/parabolic_2D.yaml')
problem_par2d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_2D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 100
#   - Lx                       : 0.0762
#   - dx                       : 0.0007620000000000001
#   - Ny                       : 100
#   - Ly                       : 0.0762
#   - dy                       : 0.0007620000000000001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 101325.0
#   - bc_xE_P_val              : 101325.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 101325.0
#   - bc_yN_P_val              : 101325.0
# - geometry:
#   - U_bot                    : 0.7
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic_2d
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 1e-14
#   - max_it                   : 40
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.2
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.0
#     - oss_alpha              : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 10     1.0000e-01   1.0000e+00   1      2.7032e+00   8.1449e-10   2.7115e+07
# 20     1.0000e-01   2.0000e+00   1      2.8608e+00   8.9781e-11   6.7111e+06
# 30     1.0000e-01   3.0000e+00   1      2.9429e+00   9.6586e-12   6.6378e+06
# 40     1.0000e-01   4.0000e+00   1      2.7028e+00   1.0346e-12   6.9214e+06
# =================================
# Total walltime   :  0:02:05
# (0.32 steps/s)
# =================================

# %%
plot_overview_2d(problem_par2d, 'Parabolic slider 2D')

# %% [markdown]
# ---
# ## Twin parabolic slider non-identical — 1D
#
# Two asymmetric parabolic sliders (hmin₁=30 µm, hmin₂=35 µm) with a flat separator and flat outlet region.
# Dirichlet ρ at ambient at both ends, periodic in y.
#
# **Reference:** Bayada et al. (Fig. 7).
#
# <img src="./figures/Geometry_TwinParabolicSlider.png"
#      alt="Twin parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider.yaml)**

# %%
problem_twin = Problem.from_yaml('../../tests/configs/twin_parabolic_slider.yaml')
regen_twin_parabolic_slider(problem_twin)
problem_twin.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.09
#   - dx                       : 0.00045
#   - Ny                       : 2
#   - Ly                       : 0.004
#   - dy                       : 0.002
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_D_val              : 877.7008
#   - bc_xE_D_val              : 877.7008
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 2.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 6e-05
#   - hmin                     : 3e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 100
#   - dt                       : 0.08
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7008
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 20000.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.0
#     - oss_alpha              : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 10     8.0000e-02   8.0000e-01   1      3.1042e-02   2.7923e-09   4.3705e+08
# 20     8.0000e-02   1.6000e+00   1      2.9149e-02   8.9803e-10   1.6805e+08
# 30     8.0000e-02   2.4000e+00   1      3.1761e-02   3.0208e-10   8.0148e+07
# 40     8.0000e-02   3.2000e+00   1      3.2748e-02   1.0436e-10   3.9313e+07
# 50     8.0000e-02   4.0000e+00   1      3.0712e-02   3.6356e-11   1.8917e+07
# 60     8.0000e-02   4.8000e+00   1      3.2661e-02   1.2699e-11   9.0666e+06
# 70     8.0000e-02   5.6000e+00   1      2.9747e-02   4.4425e-12   4.7299e+06
# 80     8.0000e-02   6.4000e+00   1      3.1358e-02   1.5563e-12   3.1971e+06
# 90     8.0000e-02   7.2000e+00   1      2.9123e-02   5.4591e-13   2.8209e+06
# 100    8.0000e-02   8.0000e+00   1      2.9778e-02   1.9176e-13   2.7579e+06
# =================================
# Total walltime   :  0:00:03
# (25.60 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin,
    title='Twin parabolic slider uneven',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider_ori.csv',
    ref_label='Bayada',
    ref_x_scale=0.09,
    ref_p_scale=1e5,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Twin parabolic slider identical — 1D
#
# Two identical symmetric parabolic sliders (hmax=50.2 µm, hmin=25.4 µm).
# High inlet pressure p_in=3.36e5 Pa, p_out≈0 Pa, periodic in y.
#
# **Reference:** Sahlin et al. / Giacopini et al., J. Tribology 132 (2010), 041702.
#
# <img src="./figures/Geometry_TwinParabolicSliderIdentical.png"
#      alt="Twin identical parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider_id.yaml)**

# %%
problem_twin_id = Problem.from_yaml('../../tests/configs/twin_parabolic_slider_id.yaml')
regen_twin_parabolic_slider_id(problem_twin_id)
problem_twin_id.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider_id.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider_id
#   - write_freq               : 50
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.0762
#   - dx                       : 0.00038100000000000005
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['N', 'N', 'N']
#   - bc_xW_P_val              : 336414.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 5.02e-05
#   - hmin                     : 2.54e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 300
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - slip_length              : 0.0
#   - EOS                      : DH
#   - rho0                     : 400.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.04
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#   - stabilization:
#     - ad                     : False
#     - oss                    : True
#     - ad_alpha               : 0.0
#     - oss_alpha              : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# ------------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual     |R| Newton
# ------------------------------------------------------------------------------
# 50     1.0000e-01   5.0000e+00   1      6.8115e-02   6.7783e-10   3.1167e+06
# 100    1.0000e-01   1.0000e+01   1      7.0224e-02   7.4322e-11   1.7319e+06
# 150    1.0000e-01   1.5000e+01   1      6.6782e-02   1.4958e-11   6.2596e+05
# 200    1.0000e-01   2.0000e+01   1      6.9301e-02   1.6834e-12   7.6537e+05
# 250    1.0000e-01   2.5000e+01   1      6.7562e-02   2.1511e-13   6.8777e+05
# 300    1.0000e-01   3.0000e+01   1      7.1943e-02   3.0077e-14   6.7275e+05
# =================================
# Total walltime   :  0:00:23
# (12.65 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin_id,
    title='Twin parabolic slider identical',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider_id.csv',
    ref_label='Sahlin',
    ref_x_scale=problem_twin_id.grid['Lx'],
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)
