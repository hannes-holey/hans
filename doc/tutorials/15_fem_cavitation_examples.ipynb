# %% [markdown]
# Cavitation Examples

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from GaPFlow.problem import Problem
from utils.plotting import plot_overview_1d, plot_overview_2d, plot_midsection_2d
from utils.topography import (
    regen_conv_slider_pocket_1d,
    regen_conv_slider_pocket_2d,
    regen_twin_parabolic_slider,
    regen_twin_parabolic_slider_id,
)

DATA_DIR = Path('../../tests/data')

# %% [markdown]
# ---
# ## Convergent slider with pocket — 1D
#
# Linear converging wedge (1.1→1.0 µm) with a 0.4 µm rectangular pocket at x∈[4,10] mm.
# Periodic in y (effectively 1D). Dirichlet p=1e5 Pa at inlet and outlet.
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# <img src="./figures/Geometry_ConvSliderPocket.png"
#      alt="Conv. slider with pocket geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_1D.yaml)**

# %%
problem_1d = Problem.from_yaml('../../tests/configs/conv_slider_pocket_1D.yaml')
regen_conv_slider_pocket_1d(problem_1d)
problem_1d.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_1D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_1D
#   - write_freq               : 50
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 128
#   - Lx                       : 0.02
#   - dx                       : 0.00015625
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 50
#   - dt                       : 1.0
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 6220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - piezo:
#     - name                   : Barus
#     - aB                     : 1.2e-08
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.05
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0001
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=100000 Pa  min=100000  max=100000
#   BC pressure E: mean=100000 Pa  min=100000  max=100000
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 2463988.3548219805
#
# Jacobian block norms (unscaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       1.46e+02   0.00e+00   1.50e-02   6.09e+04   0.00e+00
#   momentum_y       0.00e+00   1.46e+02   2.35e-03   0.00e+00   0.00e+00
#   mass             1.67e+05   2.62e+04   1.88e-02   1.37e+08   1.02e-06
#   fb               0.00e+00   0.00e+00   0.00e+00   1.91e-06   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   5.84e+07   1.91e-06
#
# Jacobian block norms (scaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       9.84e-01   0.00e+00   1.00e+00   5.02e-01   0.00e+00
#   momentum_y       0.00e+00   1.00e+00   4.90e-01   0.00e+00   0.00e+00
#   mass             9.93e-01   5.06e-02   1.10e-03   1.00e+00   2.22e-01
#   fb               0.00e+00   0.00e+00   0.00e+00   9.69e-01   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   9.99e-01   9.77e-01
#
#   Characteristic scales: jx=1.44e+01  jy=4.43e+01  p=1.45e-03  theta=1.17e+04  xi=3.91e-10  R_momentum_x=1.03e+01  R_momentum_y=3.31e+00  R_mass=1.17e+04  R_fb=1.68e-10  R_R_oss=4.99e+03
#   R_scaled=5.035549e+02
# 2340715.4887398207
#   R_scaled=4.775858e+02
# 2238599.2923484957
#   R_scaled=4.540844e+02
# 2147672.965402853
#   R_scaled=4.367059e+02
# 2056376.2621502937
#   R_scaled=4.170182e+02
# 1983765.414853923
#   R_scaled=3.966584e+02
# 1885968.56319565
#   R_scaled=3.775971e+02
# 1798336.9214379725
#   R_scaled=3.582496e+02
# 1711549.8804099446
#   R_scaled=3.405918e+02
# 1627608.9863483286
#   R_scaled=3.241088e+02
# 1549394.3980677056
#   R_scaled=3.087899e+02
# 1475954.8760995036
#   R_scaled=2.943955e+02
# 1406627.0243112538
#   R_scaled=2.807835e+02
# 1340933.4921596926
#   R_scaled=2.678558e+02
# 1278513.0321817782
#   R_scaled=2.555328e+02
# 1219074.8798540405
#   R_scaled=2.437447e+02
# 1162351.282556491
#   R_scaled=2.324136e+02
# 1108144.8027036337
#   R_scaled=2.214887e+02
# 1056279.2680681897
#   R_scaled=2.109256e+02
# 1006614.2140618223
#   R_scaled=2.006948e+02
# 959227.8380962163
#   R_scaled=1.908397e+02
# 914223.8238076348
#   R_scaled=1.814955e+02
# 871485.1983006464
#   R_scaled=1.726357e+02
# 830898.6849529507
#   R_scaled=1.642346e+02
# 792356.716049221
#   R_scaled=1.562664e+02
# 755759.2938382827
#   R_scaled=1.487051e+02
# 721008.6349236149
#   R_scaled=1.415215e+02
# 688018.1069199869
#   R_scaled=1.346850e+02
# 656706.5368404591
#   R_scaled=1.281676e+02
# 626999.3393052879
#   R_scaled=1.224741e+02
# 598015.2747627939
#   R_scaled=1.181017e+02
# 575233.3785440294
#   R_scaled=1.162877e+02
# 562872.6862614129
#   R_scaled=1.163732e+02
# 559286.5555053072
#   R_scaled=1.181585e+02
# 561865.1615908033
#   R_scaled=1.212623e+02
# 567552.7687123915
#   R_scaled=1.251696e+02
# 573648.908888781
#   R_scaled=1.293460e+02
# 578217.8469482615
#   R_scaled=1.332860e+02
# 580509.0060902073
#   R_scaled=1.366753e+02
# 580560.1433027318
#   R_scaled=1.393779e+02
# 578753.5551028416
#   R_scaled=1.413849e+02
# 575529.4324210304
#   R_scaled=1.427611e+02
# 571246.6185070972
#   R_scaled=1.435808e+02
# 566200.2861461123
#   R_scaled=1.439338e+02
# 560612.0427537976
#   R_scaled=1.439035e+02
# 554647.3807911337
#   R_scaled=1.435628e+02
# 548417.4810476357
#   R_scaled=1.429719e+02
# 542025.0877932971
#   R_scaled=1.421833e+02
# 535542.6451237231
#   R_scaled=1.412408e+02
# 529026.0791684007
#   R_scaled=1.401802e+02
# 522519.15787687735
#   R_scaled=1.390313e+02
# 516040.7822366608
#   R_scaled=1.378139e+02
# 509632.2343688475
#   R_scaled=1.365518e+02
# 503315.2788550884
#   R_scaled=1.352616e+02
# 497107.19312580646
#   R_scaled=1.339565e+02
# 491021.78036296257
#   R_scaled=1.326478e+02
# 485055.42305309203
#   R_scaled=1.313396e+02
# 479230.5987308486
#   R_scaled=1.300437e+02
# 473553.8424811777
#   R_scaled=1.287662e+02
# 468030.0158524097
#   R_scaled=1.275115e+02
# 462662.6470751721
#   R_scaled=1.262836e+02
# 457441.5587735238
#   R_scaled=1.250812e+02
# 452380.4517657536
#   R_scaled=1.239106e+02
# 447479.75642465195
#   R_scaled=1.227736e+02
# 442739.1518981599
#   R_scaled=1.216713e+02
# 438157.7226297034
#   R_scaled=1.206045e+02
# 433723.6125778658
#   R_scaled=1.195702e+02
# 429445.3329220779
#   R_scaled=1.185720e+02
# 425320.5279901054
#   R_scaled=1.176099e+02
# 421346.50213633315
#   R_scaled=1.166837e+02
# 417520.3056208846
#   R_scaled=1.157928e+02
# 413830.3067438932
#   R_scaled=1.149339e+02
# 410281.70653380465
#   R_scaled=1.141092e+02
# 406870.9535002186
#   R_scaled=1.133181e+02
# 403594.3749099864
#   R_scaled=1.125595e+02
# 400448.22652576544
#   R_scaled=1.118327e+02
# 397421.92804073024
#   R_scaled=1.111345e+02
# 394518.5612501006
#   R_scaled=1.104663e+02
# 391734.24454078334
#   R_scaled=1.098271e+02
# 389065.0958877077
#   R_scaled=1.092158e+02
# 386507.2611237749
#   R_scaled=1.086317e+02
# 384051.53626739385
#   R_scaled=1.080717e+02
# 381699.6741952712
#   R_scaled=1.075369e+02
# 379447.93467722024
#   R_scaled=1.070263e+02
# 377292.63974753575
#   R_scaled=1.065390e+02
# 375230.1887147394
#   R_scaled=1.060740e+02
# 373252.8115464456
#   R_scaled=1.056289e+02
# 371361.4506560483
#   R_scaled=1.052045e+02
# 369552.7400299648
#   R_scaled=1.047998e+02
# 367823.40305410867
#   R_scaled=1.044139e+02
# 366170.2594658645
#   R_scaled=1.040462e+02
# 364586.8881461414
#   R_scaled=1.036947e+02
# 363073.75189145096
#   R_scaled=1.033597e+02
# 361627.9472179819
#   R_scaled=1.030406e+02
# 360246.66630611353
#   R_scaled=1.027367e+02
# 358927.1992898538
#   R_scaled=1.024472e+02
# 357664.321116952
#   R_scaled=1.021707e+02
# 356458.21984983556
#   R_scaled=1.019073e+02
# 355306.46017807955
#   R_scaled=1.016566e+02
# 354206.69747202256
#   R_scaled=1.014180e+02
# 353156.6775598654
#   R_scaled=1.011908e+02
# 352152.1960664395
#   R_scaled=1.009739e+02
# 351193.2897011589
#   R_scaled=1.007674e+02
# 350277.9543641631
#   R_scaled=1.005710e+02
# 349404.26644365443
#   R_scaled=1.003840e+02
# 348570.38138809253
#   R_scaled=1.002061e+02
# 347772.94334757753
#   R_scaled=1.000362e+02
# 347011.91011966445
#   R_scaled=9.987465e+01
# 346285.65386639134
#   R_scaled=9.972091e+01
# 345592.6153840753
#   R_scaled=9.957465e+01
# 344931.30223050376
#   R_scaled=9.943551e+01
# 344299.05120431737
#   R_scaled=9.930272e+01
# 343695.78271749883
#   R_scaled=9.917640e+01
# 343120.1863284344
#   R_scaled=9.905625e+01
# 342571.00863363844
#   R_scaled=9.894195e+01
# 342047.0513491867
#   R_scaled=9.883323e+01
# 341546.20947365905
#   R_scaled=9.872949e+01
# 341068.38924558775
#   R_scaled=9.863082e+01
# 340612.542123716
#   R_scaled=9.853697e+01
# 340177.66616630455
#   R_scaled=9.844771e+01
# 339762.8042646583
#   R_scaled=9.836281e+01
# 339366.2972372552
#   R_scaled=9.828182e+01
# 338988.04971862934
#   R_scaled=9.820478e+01
# 338627.22613104305
#   R_scaled=9.813151e+01
# 338283.02854064625
#   R_scaled=9.806183e+01
# 337954.6951167619
#   R_scaled=9.799556e+01
# 337640.9205241695
#   R_scaled=9.793234e+01
# 337341.6142707397
#   R_scaled=9.787221e+01
# 337056.1122714616
#   R_scaled=9.781503e+01
# 336783.7806182775
#   R_scaled=9.776065e+01
# 336524.01428696857
#   R_scaled=9.770893e+01
# 336275.78758622054
#   R_scaled=9.765959e+01
# 336039.01793999603
#   R_scaled=9.761267e+01
# 335813.1784692104
#   R_scaled=9.756805e+01
# 335597.7663684236
#   R_scaled=9.752561e+01
# 335392.30183831713
#   R_scaled=9.748526e+01
# 335195.97954758746
#   R_scaled=9.744676e+01
# 335008.7259720558
#   R_scaled=9.741015e+01
# 334830.1235433639
#   R_scaled=9.737533e+01
# 334659.7738371633
#   R_scaled=9.734222e+01
# 334497.2967055274
#   R_scaled=9.731073e+01
# 334342.0601351341
#   R_scaled=9.728069e+01
# 334193.9997417875
#   R_scaled=9.725212e+01
# 334052.7848126098
#   R_scaled=9.722495e+01
# 333918.0998264294
#   R_scaled=9.719912e+01
# 333789.64375621045
#   R_scaled=9.717455e+01
# 333666.9207404562
#   R_scaled=9.715111e+01
# 333549.8750783159
#   R_scaled=9.712882e+01
# 333438.2449537903
#   R_scaled=9.710762e+01
# 333331.7805907074
#   R_scaled=9.708746e+01
# 333230.243696936
#   R_scaled=9.706829e+01
# 333133.2452869993
#   R_scaled=9.705000e+01
# 333040.73762325523
#   R_scaled=9.703261e+01
# 332952.51348497125
#   R_scaled=9.701607e+01
# 332868.37518776464
#   R_scaled=9.700034e+01
# 332788.1341408592
#   R_scaled=9.698538e+01
# 332711.4852176433
#   R_scaled=9.697111e+01
# 332638.3878148377
#   R_scaled=9.695754e+01
# 332568.6779506901
#   R_scaled=9.694463e+01
# 332502.19919400197
#   R_scaled=9.693236e+01
# 332438.80231287435
#   R_scaled=9.692069e+01
# 332378.24796516576
#   R_scaled=9.690955e+01
# 332320.50183544727
#   R_scaled=9.689896e+01
# 332265.43417648715
#   R_scaled=9.688889e+01
# 332212.921217207
#   R_scaled=9.687931e+01
# 332162.84488567925
#   R_scaled=9.687021e+01
# 332115.0174434697
#   R_scaled=9.686152e+01
# 332069.4100470167
#   R_scaled=9.685325e+01
# 332025.9200502096
#   R_scaled=9.684540e+01
# 331984.4495376759
#   R_scaled=9.683792e+01
# 331944.90510212455
#   R_scaled=9.683081e+01
# 331907.1394803293
#   R_scaled=9.682403e+01
# 331871.1285492058
#   R_scaled=9.681759e+01
# 331836.7911139522
#   R_scaled=9.681145e+01
# 331804.04972316854
#   R_scaled=9.680562e+01
# 331772.83049441414
#   R_scaled=9.680008e+01
# 331743.0179165161
#   R_scaled=9.679479e+01
# 331714.59189907124
#   R_scaled=9.678975e+01
# 331687.48822619766
#   R_scaled=9.678497e+01
# 331661.64564432064
#   R_scaled=9.678042e+01
# 331637.00572362833
#   R_scaled=9.677609e+01
# 331613.47785920947
#   R_scaled=9.677196e+01
# 331591.04538825847
#   R_scaled=9.676803e+01
# 331569.6575312057
#   R_scaled=9.676430e+01
# 331549.2658539516
#   R_scaled=9.676075e+01
# 331529.8241573764
#   R_scaled=9.675737e+01
# 331511.2613734886
#   R_scaled=9.675415e+01
# 331493.56373267673
#   R_scaled=9.675108e+01
# 331476.691090079
#   R_scaled=9.674817e+01
# 331460.60515601886
#   R_scaled=9.674540e+01
# 331445.26940718596
#   R_scaled=9.674276e+01
# 331430.6281051048
#   R_scaled=9.674025e+01
# 331416.6699074075
#   R_scaled=9.673786e+01
# 331403.3630832611
#   R_scaled=9.673558e+01
# 331390.6773702082
#   R_scaled=9.673342e+01
# 331378.5839035715
#   R_scaled=9.673136e+01
# 331367.0389675225
#   R_scaled=9.672940e+01
# 331356.0332479167
#   R_scaled=9.672754e+01
# 331345.5416734001
#   R_scaled=9.672576e+01
# 331335.5403292202
#   R_scaled=9.672407e+01
# 331326.0064091332
#   R_scaled=9.672247e+01
# 331316.90563073574
#   R_scaled=9.672094e+01
# 331308.23036848323
#   R_scaled=9.671948e+01
# 331299.96081411425
#   R_scaled=9.671810e+01
# 331292.07807680895
#   R_scaled=9.671678e+01
# 331284.56414100615
#   R_scaled=9.671553e+01
# 331277.392124969
#   R_scaled=9.671433e+01
# 331270.5558009448
#   R_scaled=9.671320e+01
# 331264.03952420806
#   R_scaled=9.671212e+01
# 331257.8283768115
#   R_scaled=9.671109e+01
# 331251.90813190094
#   R_scaled=9.671011e+01
# 331246.2577125527
#   R_scaled=9.670918e+01
# 331240.8720438263
#   R_scaled=9.670829e+01
# 331235.73877378803
#   R_scaled=9.670745e+01
# 331230.846125295
#   R_scaled=9.670665e+01
# 331226.1828666309
#   R_scaled=9.670589e+01
# 331221.7324726567
#   R_scaled=9.670516e+01
# 331217.49081939645
#   R_scaled=9.670447e+01
# 331213.44815663795
#   R_scaled=9.670381e+01
# 331209.5951894042
#   R_scaled=9.670318e+01
# 331205.92305340717
#   R_scaled=9.670259e+01
# 331202.4187945133
#   R_scaled=9.670202e+01
# 331199.07906676934
#   R_scaled=9.670148e+01
# 331195.8961767924
#   R_scaled=9.670097e+01
# 331192.8627898963
#   R_scaled=9.670048e+01
# 331189.97191319533
#   R_scaled=9.670001e+01
# 331187.2133925371
#   R_scaled=9.669957e+01
# 331184.584519477
#   R_scaled=9.669915e+01
# 331182.0792251815
#   R_scaled=9.669875e+01
# 331179.69172410923
#   R_scaled=9.669837e+01
# 331177.41650003736
#   R_scaled=9.669801e+01
# 331175.24559542455
#   R_scaled=9.669766e+01
# 331173.1768211532
#   R_scaled=9.669733e+01
# 331171.2053918198
#   R_scaled=9.669702e+01
# 331169.32674496406
#   R_scaled=9.669672e+01
# 331167.53653083206
#   R_scaled=9.669644e+01
# 331165.82851452497
#   R_scaled=9.669617e+01
# 331164.200928837
#   R_scaled=9.669592e+01
# 331162.6500019175
#   R_scaled=9.669567e+01
# 331161.17213666334
#   R_scaled=9.669544e+01
# 331159.76390459115
#   R_scaled=9.669522e+01
# 331158.4204192626
#   R_scaled=9.669501e+01
# 331157.14025831025
#   R_scaled=9.669481e+01
# 331155.92044876167
#   R_scaled=9.669462e+01
# 331154.7581559209
#   R_scaled=9.669444e+01
# 331153.6506769343
#   R_scaled=9.669427e+01
# 331152.5941857904
#   R_scaled=9.669410e+01
# 331151.58753752976
#   R_scaled=9.669395e+01
# 331150.628388859
#   R_scaled=9.669380e+01
# 331149.7145071454
#   R_scaled=9.669366e+01
# 50     1.0000e+00   5.0000e+01   5      2.8896e-01   1.4530e-15
# =================================
# Total walltime   :  0:00:15
# (3.13 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_1d,
    title='Conv. slider + pocket 1D (Bertocchi 2013)',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_1D.csv',
    ref_label='Bertocchi (ref.)',
    ref_x_scale=0.020,
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)

# %% [markdown]
# ---
# ## Convergent slider with pocket — 2D
#
# **Reference:** Bertocchi et al., Trib. Int. 67 (2013), 61–71.
#
# $\rightarrow$ **[YAML File](../../tests/configs/conv_slider_pocket_2D.yaml)**

# %%
problem_2d_pocket = Problem.from_yaml('../../tests/configs/conv_slider_pocket_2D.yaml')
regen_conv_slider_pocket_2d(problem_2d_pocket)
problem_2d_pocket.run()
# Out:
# Reading input file: ../../tests/configs/conv_slider_pocket_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/conv_slider_pocket_2D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 360
#   - Lx                       : 0.02
#   - dx                       : 5.555555555555556e-05
#   - Ny                       : 60
#   - Ly                       : 0.01
#   - dy                       : 0.00016666666666666666
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 100000.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 100000.0
#   - bc_yN_P_val              : 100000.0
# - geometry:
#   - U_bot                    : 1.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 1.1e-06
#   - hmin                     : 1e-06
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 12
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.01
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 850.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 5
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.15
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=100000 Pa  min=100000  max=100000
#   BC pressure E: mean=100000 Pa  min=100000  max=100000
#   BC pressure S: mean=100000 Pa  min=100000  max=100000
#   BC pressure N: mean=100000 Pa  min=100000  max=100000
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 472220.72683958715
# 401637.0140917277
# 2353398.660929052
# 2068776.1773002266
# 1672804.8983688392
# 1339199.357258203
# 1055594.7588297972
# 853782.850665104
# 699233.8303557375
# 573028.0692479274
# 474706.6261771182
# 397829.3127570052
# 334119.10601109033
# 283922.0882521411
# 241284.48067668438
# 206535.74237609535
# 179028.1099942323
# 156683.21009836654
# 137414.62386180856
# 120773.3268674497
# 106464.31082431429
# 94764.141676282
# 86091.43981144502
# 79633.29291514432
# 75114.67591203384
# 72255.30031717272
# 70472.94000102267
# 69465.13986550913
# 69009.20035104797
# 68932.12792427074
# 69101.70826170723
# 69421.4512379423
# 69823.81247775708
# 70268.16794567696
# 70723.84725337247
# 71169.20529239939
# 71591.06182874544
# 71977.57846304271
# 72332.62152545979
# 72655.0797301895
# 72945.40363462114
# 73204.94270086853
# 73435.81808601978
# 73640.30769054493
# 73820.8036919001
# 73979.67039367503
# 74119.13499031971
# 74241.35110421178
# 74348.27137350348
# 74441.67517569452
# 10     1.0000e-01   1.0000e+00   5      3.2299e+01   4.4359e-12
# 74523.16976456763
# 74594.18270223941
# 74656.01382149478
# 74709.80562989926
# 74756.56904582008
# 74797.19581607786
# 74832.46465994995
# 74863.07017969033
# 74889.61637637201
# 74912.63173948387
# =================================
# Total walltime   :  0:06:24
# (0.03 steps/s)
# =================================

# %%
plot_overview_2d(problem_2d_pocket, '2D Pocketed Convergent Slider')

# %%
plot_midsection_2d(
    problem_2d_pocket,
    title='2D Pocketed Convergent Slider - Midsection',
    ref_csv=DATA_DIR / 'ref_conv_slider_pocket_2D.csv',
    ref_label='Bertocchi',
)

# %% [markdown]
# ---
# ## Parabolic slider — 1D
#
# <img src="./figures/Geometry_ParabolicSlider.png"
#      alt="Parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_slider.yaml)**

# %%
problem_par1d = Problem.from_yaml('../../tests/configs/parabolic_slider_cav.yaml')
problem_par1d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_slider.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_slider
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 256
#   - Lx                       : 0.0762
#   - dx                       : 0.00029765625
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 100000.0
#   - bc_xE_P_val              : 0.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 50
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : True
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.001
#   - oss_theta_alpha          : 1.0
#   - oss_correction_alpha     : 1.0
#   - p_init                   : 103338.25
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=100000 Pa  min=100000  max=100000
#   BC pressure E: mean=7.0762e-06 Pa  min=7.0762e-06  max=7.0762e-06
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 62547209.11672937
#
# Jacobian block norms (unscaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       1.96e+00   0.00e+00   2.13e-02   3.84e+03   0.00e+00
#   momentum_y       0.00e+00   1.96e+00   6.34e-03   0.00e+00   0.00e+00
#   mass             3.70e+06   1.10e+06   3.49e-01   1.43e+10   2.75e-06
#   fb               0.00e+00   0.00e+00   0.00e+00   5.14e-06   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   6.11e+09   5.14e-06
#
# Jacobian block norms (scaled)
#   res \ var              jx         jy          p      theta         xi
#   ---------------------------------------------------------------------
#   momentum_x       1.52e-01   0.00e+00   9.95e-01   7.77e-02   0.00e+00
#   momentum_y       0.00e+00   9.93e-01   1.00e+00   0.00e+00   0.00e+00
#   mass             9.92e-01   5.73e-01   5.63e-05   1.00e+00   2.22e-01
#   fb               0.00e+00   0.00e+00   0.00e+00   9.66e-01   0.00e+00
#   R_oss            0.00e+00   0.00e+00   0.00e+00   9.99e-01   9.74e-01
#
#   Characteristic scales: jx=3.11e+01  jy=1.61e+01  p=5.18e-02  theta=1.20e+05  xi=1.03e-10  R_momentum_x=4.14e-01  R_momentum_y=1.23e-01  R_mass=1.20e+05  R_fb=4.45e-11  R_R_oss=5.11e+04
#   R_scaled=8.967256e+02
# 56292320.26039914
#   R_scaled=7.982096e+02
# 159879160.95494166
#   R_scaled=1.995853e+03
# 158189077.58054185
#   R_scaled=1.996135e+03
# 155487086.5186226
#   R_scaled=1.972585e+03
# 139755879.87591693
#   R_scaled=1.775160e+03
# 124838443.91384292
#   R_scaled=1.610703e+03
# 114641141.45423101
#   R_scaled=1.481286e+03
# 112213324.93445586
#   R_scaled=1.738274e+03
# 101172409.17325586
#   R_scaled=1.583542e+03
# 10     1.0000e-01   1.0000e+00   1      1.3518e-01   5.4928e-10
# 89544864.25744271
#   R_scaled=1.404356e+03
# 79731849.15634361
#   R_scaled=1.251658e+03
# 71339704.835454
#   R_scaled=1.119947e+03
# 64073974.32936735
#   R_scaled=1.005179e+03
# 57715164.510943756
#   R_scaled=9.042966e+02
# 52099366.55895255
#   R_scaled=8.149723e+02
# 47103299.55183578
#   R_scaled=7.354215e+02
# 42633091.321718454
#   R_scaled=6.642558e+02
# 38616051.25291671
#   R_scaled=6.003754e+02
# 34994742.76969776
#   R_scaled=5.428916e+02
# 20     1.0000e-01   2.0000e+00   1      2.0408e-01   1.3779e-10
# 31722769.037570965
#   R_scaled=4.910714e+02
# 28761804.791471604
#   R_scaled=4.442988e+02
# 26079517.997510865
#   R_scaled=4.020465e+02
# 23648117.902453933
#   R_scaled=3.638569e+02
# 21443339.121007066
#   R_scaled=3.293277e+02
# 19443726.61736509
#   R_scaled=2.981022e+02
# 17630126.941330027
#   R_scaled=2.698614e+02
# 15985320.1781664
#   R_scaled=2.443192e+02
# 14493747.64875076
#   R_scaled=2.212175e+02
# 13141304.769143574
#   R_scaled=2.003233e+02
# 30     1.0000e-01   3.0000e+00   1      1.5038e-01   4.1457e-11
# 11915178.415527869
#   R_scaled=1.814257e+02
# 10803714.950038847
#   R_scaled=1.643340e+02
# 9796309.690883081
#   R_scaled=1.488753e+02
# 8883311.729570651
#   R_scaled=1.348931e+02
# 8055940.082909884
#   R_scaled=1.222457e+02
# 7306208.5473536495
#   R_scaled=1.108048e+02
# 6626857.527189794
#   R_scaled=1.004545e+02
# 6011291.692638582
#   R_scaled=9.108973e+01
# 5453522.696616494
#   R_scaled=8.261573e+01
# 4948116.412469898
#   R_scaled=7.494679e+01
# 40     1.0000e-01   4.0000e+00   1      1.3211e-01   1.3622e-11
# 4490144.298458911
#   R_scaled=6.800551e+01
# 4075138.5808965946
#   R_scaled=6.172200e+01
# 3699050.9984272057
#   R_scaled=5.603316e+01
# 3358214.8789640698
#   R_scaled=5.088206e+01
# 3049310.3375685923
#   R_scaled=4.621733e+01
# 2769332.3935757624
#   R_scaled=4.199261e+01
# 2515561.8123147627
#   R_scaled=3.816610e+01
# 2285538.4824572275
#   R_scaled=3.470007e+01
# 2077037.145878172
#   R_scaled=3.156050e+01
# 1888045.3031728885
#   R_scaled=2.871671e+01
# 50     1.0000e-01   5.0000e+00   1      1.2947e-01   4.6341e-12
# =================================
# Total walltime   :  0:00:08
# (5.97 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_par1d,
    title='Parabolic slider 1D',
    ref_csv=DATA_DIR / 'ref_parabolic_slider.csv',
    ref_label='Bayada',
    ref_x_scale=problem_par1d.grid['Lx'],
    ref_p_scale=1.0,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Parabolic slider — 2D
#
# $\rightarrow$ **[YAML File](../../tests/configs/parabolic_2D.yaml)**

# %%
problem_par2d = Problem.from_yaml('../../tests/configs/parabolic_2D.yaml')
problem_par2d.run()
# Out:
# Reading input file: ../../tests/configs/parabolic_2D.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/parabolic_2D
#   - write_freq               : 10
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 50
#   - Lx                       : 0.0762
#   - dx                       : 0.0015240000000000002
#   - Ny                       : 50
#   - Ly                       : 0.0762
#   - dy                       : 0.0015240000000000002
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_P_val              : 101325.0
#   - bc_xE_P_val              : 101325.0
#   - bc_yS                    : ['D', 'N', 'N']
#   - bc_yN                    : ['D', 'N', 'N']
#   - bc_yS_P_val              : 101325.0
#   - bc_yN_P_val              : 101325.0
# - geometry:
#   - U_bot                    : 0.7
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : parabolic_2d
#   - flip                     : False
#   - hmin                     : 2.54e-05
#   - hmax                     : 5.08e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 1e-14
#   - max_it                   : 40
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7007
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.2
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=101325 Pa  min=101325  max=101325
#   BC pressure E: mean=101325 Pa  min=101325  max=101325
#   BC pressure S: mean=101325 Pa  min=101325  max=101325
#   BC pressure N: mean=101325 Pa  min=101325  max=101325
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 62555382.7258328
# 50044306.17995202
# 40035472.485966995
# 40561714.11470358
# 51883921.54474549
# 49388716.46676159
# 39607344.842840895
# 31872802.47184358
# 25954374.824080717
# 21627151.098928615
# 10     1.0000e-01   1.0000e+00   1      4.8542e-01   1.5418e-09
# 18606331.995657157
# 16470426.687808586
# 14941360.8756796
# 13854922.339132821
# 13057894.89572257
# 12389792.41863525
# 11816769.30402941
# 11378967.667123822
# 11047319.259135619
# 10753372.04532137
# 20     1.0000e-01   2.0000e+00   1      5.0476e-01   2.4026e-10
# 10526904.168094901
# 10400790.419504529
# 10341074.195343332
# 10343397.311818892
# 10393012.819741724
# 10473365.204871442
# 10568463.808153715
# 10665449.0270929
# 10774919.354579149
# 10893569.605335036
# 30     1.0000e-01   3.0000e+00   1      4.9372e-01   6.4500e-11
# 11010591.719291646
# 11120306.871368892
# 11220413.473534072
# 11310393.14532035
# 11390619.207397696
# 11460604.35208961
# 11517267.778535875
# 11567974.519924833
# 11613278.063535584
# 11653690.092463065
# 40     1.0000e-01   4.0000e+00   1      4.7880e-01   1.1288e-11
# =================================
# Total walltime   :  0:00:20
# (1.96 steps/s)
# =================================

# %%
plot_overview_2d(problem_par2d, 'Parabolic slider 2D')

# %% [markdown]
# ---
# ## Twin parabolic slider non-identical — 1D
#
# Two asymmetric parabolic sliders (hmin₁=30 µm, hmin₂=35 µm) with a flat separator and flat outlet region.
# Dirichlet ρ at ambient at both ends, periodic in y.
#
# **Reference:** Bayada et al. (Fig. 7).
#
# <img src="./figures/Geometry_TwinParabolicSlider.png"
#      alt="Twin parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider.yaml)**

# %%
problem_twin = Problem.from_yaml('../../tests/configs/twin_parabolic_slider.yaml')
regen_twin_parabolic_slider(problem_twin)
problem_twin.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider
#   - write_freq               : 100
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.09
#   - dx                       : 0.00045
#   - Ny                       : 2
#   - Ly                       : 0.004
#   - dy                       : 0.002
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['D', 'N', 'N']
#   - bc_xW_D_val              : 877.7008
#   - bc_xE_D_val              : 877.7008
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 2.0
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 6e-05
#   - hmin                     : 3e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 100
#   - dt                       : 0.08
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 877.7008
#   - P0                       : 101325.0
#   - C1                       : 35000000000.0
#   - C2                       : 1.23
#   - p_cav                    : 20000.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.1
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=101325 Pa  min=101325  max=101325
#   BC pressure E: mean=101325 Pa  min=101325  max=101325
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 87347538.90521008
# 78612891.14671141
# 1012236112.2204114
# 883445602.5100523
# 772134697.4064922
# 678394198.0301353
# 582546235.113926
# 542397339.6335539
# 512647206.08446556
# 453278424.2255472
# 402311659.6713594
# 358333721.3578016
# 320249550.4862817
# 287155380.8948088
# 258306196.61685172
# 233041971.70074686
# 210563537.74451032
# 190551683.27306795
# 172663710.56693318
# 156585901.4612096
# 142067459.08800852
# 128914214.66578157
# 116973149.3233834
# 106119687.82100931
# 96249121.40596521
# 87271044.89046632
# 79105746.41952562
# 71681846.33416206
# 64934735.71413749
# 58805525.25609822
# 53240316.687904425
# 48189674.47892181
# 43608219.12422122
# 39454293.19570537
# 35689671.82471098
# 32279302.465353847
# 29191066.385803413
# 26395558.124982048
# 23865880.772664946
# 21577455.54896028
# 19507844.41069448
# 17636584.563954428
# 15945033.900592623
# 14416226.521093765
# 13034737.652267827
# 11786557.402865987
# 10658972.91017705
# 9640458.508433405
# 8720573.595001865
# 7889867.888156395
# 7139793.768671161
# 6462625.384569047
# 5851384.180819694
# 5299770.497388946
# 4802100.86493476
# 4353250.614046181
# 3948601.4065675084
# 3583993.2922541057
# 3255680.891225858
# 2960293.302066145
# 2694797.337068809
# 2456463.6913897097
# 2242835.6645774506
# 2051700.0758476923
# 1881060.0551828973
# 1729109.458807538
# 1594208.7571296315
# 1474862.379046004
# 1369697.662620704
# 1277445.73794717
# 1196924.8157634395
# 1127026.4240648744
# 1066705.0745898008
# 1014971.6250985294
# 970890.2509777928
# 933578.5233480805
# 902209.7188583108
# 876016.2643653434
# 854293.2065558685
# 836400.7838526512
# 821765.4976537898
# 809879.4375056407
# 800297.9268592885
# 792635.7728205785
# 786562.5130781195
# 781797.0720916812
# 778102.1957093473
# 775278.9584470367
# 773161.5540815119
# 771612.5029330774
# 770518.345694287
# 769785.8459617189
# 769338.6907036366
# 769114.6572059985
# 769063.2036151529
# 769143.435456831
# 769322.4001100985
# 769573.6635959441
# 769876.1278671718
# 770213.0513398246
# 100    8.0000e-02   8.0000e+00   1      4.4787e-02   1.8651e-13
# =================================
# Total walltime   :  0:00:04
# (20.36 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin,
    title='Twin parabolic slider uneven',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider.csv',
    ref_label='Bayada',
    ref_x_scale=0.09,
    ref_p_scale=1e5,
    p_unit='bar', p_divisor=1e5,
)

# %% [markdown]
# ---
# ## Twin parabolic slider identical — 1D
#
# Two identical symmetric parabolic sliders (hmax=50.2 µm, hmin=25.4 µm).
# High inlet pressure p_in=3.36e5 Pa, p_out≈0 Pa, periodic in y.
#
# **Reference:** Sahlin et al. / Giacopini et al., J. Tribology 132 (2010), 041702.
#
# <img src="./figures/Geometry_TwinParabolicSliderIdentical.png"
#      alt="Twin identical parabolic slider geometry"
#      width="250">
#
# $\rightarrow$ **[YAML File](../../tests/configs/twin_parabolic_slider_id.yaml)**

# %%
problem_twin_id = Problem.from_yaml('../../tests/configs/twin_parabolic_slider_id.yaml')
regen_twin_parabolic_slider_id(problem_twin_id)
problem_twin_id.run()
# Out:
# Reading input file: ../../tests/configs/twin_parabolic_slider_id.yaml
# *************************************************************
# *                       PROBLEM SETUP                       *
# *************************************************************
# - options:
#   - output                   : /tmp/twin_parabolic_slider_id
#   - write_freq               : 50
#   - use_tstamp               : True
#   - save_output              : False
#   - print_progress           : True
#   - print_metrics            : False
#   - output_plots             : False
#   - residual_analysis        : False
# - grid:
#   - Nx                       : 200
#   - Lx                       : 0.0762
#   - dx                       : 0.00038100000000000005
#   - Ny                       : 4
#   - Ly                       : 0.004
#   - dy                       : 0.001
#   - dim                      : 2
#   - bc_xW                    : ['D', 'N', 'N']
#   - bc_xE                    : ['N', 'N', 'N']
#   - bc_xW_P_val              : 336414.0
#   - bc_yS                    : ['P', 'P', 'P']
#   - bc_yN                    : ['P', 'P', 'P']
# - geometry:
#   - U_bot                    : 4.57
#   - V_bot                    : 0.0
#   - U_top                    : 0.0
#   - V_top                    : 0.0
#   - type                     : inclined
#   - flip                     : False
#   - hmax                     : 5.02e-05
#   - hmin                     : 2.54e-05
# - numerics:
#   - solver                   : fem
#   - tol                      : 0.0
#   - max_it                   : 250
#   - dt                       : 0.1
#   - adaptive                 : False
#   - CFL                      : 0.5
#   - MC_order                 : 1
# - properties:
#   - shear                    : 0.039
#   - bulk                     : 0.0
#   - force_x                  : 0.0
#   - force_y                  : 0.0
#   - EOS                      : DH
#   - rho0                     : 400.0
#   - P0                       : 100000.0
#   - C1                       : 2220000000.0
#   - C2                       : 1.66
#   - p_cav                    : 0.0
#   - elastic:
#     - enabled                : False
# - gp:
# - db:
# - md:
# - fem_solver:
#   - dynamic                  : True
#   - type                     : newton_alpha
#   - max_iter                 : 1
#   - R_norm_tol               : 1e-09
#   - newton_relax             : 0.02
#   - newton_debug             : None
#   - scaling                  : False
#   - linear_solver            : direct
#   - physics:
#     - gap_shear              : True
#     - plane_shear            : False
#     - inertia                : False
#     - body_force             : False
#     - energy                 : False
#     - energy_convection      : True
#     - pressure_work          : True
#     - thermal_diffusion      : True
#     - wall_heat_balance      : True
#     - wall_shear_work        : True
#     - theta_stab             : False
#     - oss_theta              : True
#   - theta_stab_alpha         : 0.0
#   - oss_theta_alpha          : 2.0
#   - oss_correction_alpha     : 1.0
#   - equations:
#     - energy                 : False
#     - term_list              : None
#     - cavitation             : True
#   - log_jacobian_block_norms : False
#   - scaling_update_interval  : 100
#   - scaling_ruiz_iter        : 10
#   - nodal_diagnostics        : False
#   - line_search              : False
#   - line_search_alpha_min    : 1e-12
#   - theta_min                : 2.220446049250313e-16
# - energy_spec:
# - force_balance:
# *************************************************************
# *                  PROBLEM SETUP COMPLETED                  *
# *************************************************************
# [FEMSolver2d] Using reference pressure p_ref = 1.000e+05 Pa for scaling
#   BC pressure W: mean=336414 Pa  min=336414  max=336414
# ---------------------------------------------------------------------------
# Step   Timestep     Time         Iter   Conv. Time   Residual
# ---------------------------------------------------------------------------
# 3049325.442881959
# 2989648.3499394995
# 2938659.08029735
# 2882764.0728650168
# 2865095.5928742117
# 3373679.8920143754
# 3826229.180851561
# 5644104.268792539
# 4967207.8791946145
# 5264215.31242112
# 4732124.926223841
# 4610423.2274495475
# 4276078.282303911
# 4836089.816669031
# 4371748.154221726
# 4700192.143816468
# 4221900.965922918
# 4478359.621658276
# 4041390.0343474946
# 4449020.968245283
# 3963947.076834167
# 4291880.146104569
# 3866727.624023022
# 4095453.6089983657
# 3753034.2131287013
# 3927922.9743010686
# 3680437.7294739154
# 3750885.940198007
# 3628422.174632608
# 3560931.545709003
# 3569086.4904400664
# 3379759.4679155718
# 3420427.8217248414
# 3223917.462520802
# 3383570.9913131264
# 3018510.116272113
# 3326958.944252685
# 2874505.970197831
# 3224231.9501879537
# 3086919.0426849173
# 3002060.70075075
# 3270981.2835179414
# 2792802.8022805504
# 2939088.859770065
# 2884565.08163684
# 2563299.1009489647
# 2947356.974118162
# 2869609.9268064452
# 2558315.3907497497
# 2921508.8212544853
# 50     1.0000e-01   5.0000e+00   1      8.7150e-02   6.4868e-10
# 2852275.7090278985
# 2416172.212348837
# 2744564.0681813047
# 2708953.9238155973
# 2278379.8032225394
# 2477141.0761188325
# 2501857.058311538
# 2366446.444715002
# 2192013.0461079474
# 2335389.7834003307
# 2299654.821365139
# 1985944.8192579304
# 2305273.05811035
# 2385748.541166106
# 2343048.1620994476
# 1955445.265733132
# 2117408.490092051
# 2200518.196060448
# 2184186.303814056
# 1917193.2535455276
# 1907898.567178957
# 2060312.670228694
# 2073200.1078272571
# 2019231.8531730052
# 1731906.3714884904
# 1912035.2876149318
# 1980956.9029890911
# 1991602.4763776949
# 1955262.200821479
# 1670432.8942221322
# 1669221.4821423525
# 1768136.0361268118
# 1810712.4380377068
# 1824235.4946880077
# 1799959.8436315302
# 1580671.4604271394
# 1580215.41947262
# 1757211.6824772386
# 1798416.4205942329
# 1594784.7698244047
# 1644140.5747911688
# 1947925.1111304965
# 2059353.7305307265
# 2102887.442937613
# 2100324.2485374385
# 2057032.3850141086
# 1864656.2993497988
# 1676028.6075964847
# 1621095.2891680489
# 1621195.7007911634
# 100    1.0000e-01   1.0000e+01   1      8.8516e-02   2.6227e-10
# 1638370.4082388645
# 1656100.395330658
# 1669081.7027615178
# 1675410.4223367248
# 1674030.104435003
# 1664363.9312998534
# 1646084.008823346
# 1618987.5858938484
# 1583215.6339919632
# 1508343.9006582736
# 1406293.2530601872
# 1380649.2338247872
# 1394201.9574096128
# 1417581.503921016
# 1438908.2276402866
# 1455378.7214642838
# 1463012.1177548221
# 1459395.2787039282
# 1443103.72450196
# 1413437.0223255253
# 1340028.8797042987
# 1230623.186085002
# 1224519.2176815628
# 1258778.431849818
# 1295353.4203189784
# 1323134.6332430458
# 1345613.9423495543
# 1359685.6621059687
# 1363645.2193828013
# 1356711.4732839407
# 1338853.5710487717
# 1311031.2706019075
# 1275853.5174862703
# 1179462.1369868037
# 1106486.1350606708
# 1077744.5470832156
# 1074508.433826996
# 1083602.8585619398
# 1096733.1039923977
# 1109205.1782789675
# 1119346.4347752617
# 1128246.425173579
# 1135296.0049190882
# 1140062.510897221
# 1142258.9189825882
# 1141704.931922843
# 1138290.1522765446
# 1131957.7933825152
# 1122687.8753838602
# 1110490.2490421212
# 150    1.0000e-01   1.5000e+01   1      9.4279e-02   6.6808e-11
# 1095409.2419171752
# 1077533.5164398043
# 1057003.4561353254
# 1034074.6207712245
# 1009346.600009185
# 983943.4556809495
# 931229.1801569918
# 874833.2455160434
# 838555.0072437429
# 818406.7312840485
# 810403.8271502187
# 810904.42069575
# 816844.9282545506
# 825821.7112001005
# 836053.6398572018
# 846284.0438228992
# 855667.5659698106
# 863666.6379285062
# 869966.8000759839
# 874411.6587559211
# 877610.3922166942
# 880003.042785048
# 881532.6113504664
# 882161.8359055256
# 881870.0391387596
# 880650.2888435661
# 878506.8943689942
# 875453.2371334734
# 871509.9367478683
# 866700.3219342442
# 861051.0560987218
# 854591.3811909697
# 847352.3615580478
# 839366.3625312161
# 830666.7517678136
# 821287.7961066318
# 811264.7011055556
# 800633.7048901668
# 789432.1003143364
# 777698.044299306
# 765470.0672552938
# 752786.3732800216
# 739684.3435292183
# 726201.0446541937
# 712375.7503979421
# 698254.9301845933
# 683894.6136417297
# 669368.777349657
# 654776.5607324011
# 640228.987612975
# 200    1.0000e-01   2.0000e+01   1      8.4471e-02   2.3953e-11
# 625837.635097536
# 607796.9604523561
# 566422.979533498
# 531338.8720600465
# 502531.74114853714
# 479917.418603012
# 463302.2609104019
# 452358.7565080344
# 446623.8292774137
# 445522.12343804794
# 448407.98891745147
# 454614.2774639536
# 463496.1757304916
# 474462.83528283174
# 486995.06062437757
# 500651.1619267335
# 515064.616551571
# 529937.0628658964
# 545029.2904801548
# 560151.9324489075
# 575156.7958136209
# 589929.2476827117
# 604381.76499143
# 618448.5932506087
# 632081.3872056676
# 645245.6848599763
# 657918.0707806557
# 670083.900471982
# 681735.4770037715
# 692870.5901208827
# 703491.3450396728
# 713603.2225267219
# 723214.3236904952
# 732334.7624720271
# 740976.1764516211
# 749151.3326396112
# 756873.8097019766
# 764157.7418453171
# 771017.6125633888
# 777468.0887992212
# 783523.8879400116
# 789199.6715369949
# 794509.9608177878
# 799469.0699959268
# 804091.0541317919
# 808389.6689008666
# 812378.3401103847
# 816070.1411964287
# 819477.7772513501
# 822613.5743887605
# 250    1.0000e-01   2.5000e+01   1      8.1534e-02   8.9506e-12
# =================================
# Total walltime   :  0:00:25
# (9.99 steps/s)
# =================================

# %%
plot_overview_1d(
    problem_twin_id,
    title='Twin parabolic slider identical',
    ref_csv=DATA_DIR / 'ref_twin_parabolic_slider_id.csv',
    ref_label='Sahlin',
    ref_x_scale=problem_twin_id.grid['Lx'],
    ref_p_scale=1e6,
    p_unit='MPa', p_divisor=1e6,
)
