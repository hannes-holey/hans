# %%
from pylub.problem import Input
from pylub.helper.plot import Plot

# %%
myProblem = Input("journal-bearing_incomp.yaml", None).getProblem()
myProblem.__dict__
# Out:
# {'options': {'name': 'journal-bearing_incomp', 'writeInterval': 100},
#  'disc': {'dx': 2e-05, 'dy': 2e-05, 'Nx': 50, 'Ny': 50},
#  'geometry': {'type': 'journal', 'CR': 0.01, 'eps': 0.7, 'U': 0.1, 'V': 0.0},
#  'numerics': {'Rey': 1,
#   'adaptive': 1,
#   'C': 0.2,
#   'tol': 2e-12,
#   'dt': 1e-10,
#   'maxT': 3e-05,
#   'numFlux': 'MC'},
#  'material': {'EOS': 'DH',
#   'shear': 0.0794,
#   'bulk': 0.0,
#   'P0': 101325,
#   'rho0': 877.7007,
#   'T0': 323.15,
#   'C1': '3.5e10',
#   'C2': 1.23,
#   'alpha': 1.9},
#  'q_init': None}

# %%
myProblem.run()
# Out:
# Min. channel height: 4.8e-07 m
# Max. channel height: 2.7e-06 m
# Step      	Timestep    	Time        	Epsilon
#          0	1.000000e-10	1.000000e-10	1.349279e-05
#        100	3.037637e-10	3.047720e-08	2.197939e-06
#        200	3.037543e-10	6.085303e-08	9.729314e-07
#        300	3.037504e-10	9.122824e-08	3.879551e-07
#        400	3.037489e-10	1.216032e-07	1.527128e-07
#        500	3.037483e-10	1.519781e-07	5.995854e-08
#        600	3.037481e-10	1.823529e-07	2.352829e-08
#        700	3.037480e-10	2.127277e-07	9.231334e-09
#        800	3.037479e-10	2.431025e-07	3.621599e-09
#        900	3.037479e-10	2.734773e-07	1.420662e-09
#       1000	3.037479e-10	3.038520e-07	5.572237e-10
#       1100	3.037479e-10	3.342268e-07	2.185242e-10
#       1200	3.037479e-10	3.646016e-07	8.568460e-11
#       1300	3.037479e-10	3.949764e-07	3.359977e-11
#       1400	3.037479e-10	4.253512e-07	1.318230e-11
#       1500	3.037479e-10	4.557260e-07	5.187418e-12
#       1600	3.037479e-10	4.861008e-07	2.056734e-12
#       1604	3.037479e-10	4.870120e-07	1.997339e-12
#
# Solution has converged after 1604 steps, Output written to: data/journal-bearing_incomp_0001.nc
# Total wall clock time: 00:00:03 (Performance: 140275.95 ps/s)

# %%
files = Plot(".")
# Out:
# Available files:
#   0: ./data/journal-bearing_incomp_0001.nc              22/12/2020 14:24
# Enter file keys (space separated or range [start]-[end] or combination of both): 0

# %%
files.ds
# Out:
# {'./data/journal-bearing_incomp_0001.nc': <class 'netCDF4._netCDF4.Dataset'>
#  root group (NETCDF3_64BIT_OFFSET data model, file format NETCDF3):
#      tStart: 22/12/2020 14:24:32
#      commit: 1c174b30a254f0613c447f8984f94746be7b013c
#      options_name: journal-bearing_incomp
#      options_writeInterval: 100
#      disc_dx: 2e-05
#      disc_dy: 2e-05
#      disc_Nx: 50
#      disc_Ny: 50
#      disc_Lx: 0.001
#      disc_Ly: 0.001
#      geometry_type: journal
#      geometry_CR: 0.01
#      geometry_eps: 0.7
#      geometry_U: 0.1
#      geometry_V: 0.0
#      numerics_Rey: 1
#      numerics_adaptive: 1
#      numerics_C: 0.2
#      numerics_tol: 2e-12
#      numerics_dt: 1e-10
#      numerics_maxT: 3e-05
#      numerics_numFlux: MC
#      material_EOS: DH
#      material_shear: 0.0794
#      material_bulk: 0.0
#      material_P0: 101325
#      material_rho0: 877.7007
#      material_T0: 323.15
#      material_C1: 3.5e10
#      material_C2: 1.23
#      material_alpha: 1.9
#      tEnd: 22/12/2020 14:24:35
#      dimensions(sizes): x(50), y(50), step(18)
#      variables(dimensions): float64 rho(step,x,y), float64 jx(step,x,y), float64 jy(step,x,y), float64 time(step), float64 mass(step), float64 vmax(step), float64 vSound(step), float64 dt(step), float64 eps(step)
#      groups: }

# %%
# %matplotlib notebook
fig, ax = files.plot_cut(1)
# Out:
# <img src="data:image/png;base64,..." width="640">
