# %%
from hans.input import Input

myProblem = Input("elastic_2_parabolic.yaml", None).getProblem()
myProblem.run(out_dir="data")
# Out:
#  /home/qd5728/Integration/lib/python3.12/site-packages/dtoolcore/__init__.py:14: UserWarning:pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
# Reading input from elastic_2_parabolic.yaml...
# Checking I/O options...
# Checking discretization...
# Checking numerics options...
# Checking geometry...
# Checking material options...
# Checking boundary conditions...
# Sanity checks completed. Start simulation!
# ------------------------------------------------------------
# Step      	Timestep    	Time        	Epsilon
# #          0	1.000000e-10	0.000000e+00	inf
# #       2000	7.594538e-13	1.618148e-09	3.135966e-08
# #       4000	7.594536e-13	3.137056e-09	1.990964e-07
# #       6000	7.594534e-13	4.655963e-09	5.778898e-07
# #       8000	7.594533e-13	6.174870e-09	1.249734e-06
# #      10000	7.594531e-13	7.693776e-09	2.283073e-06
# #      12000	7.594529e-13	9.212682e-09	3.761236e-06
# #      14000	7.594527e-13	1.073159e-08	5.705649e-06
# #      16000	7.594525e-13	1.225049e-08	8.176489e-06
# #      18000	7.594523e-13	1.376940e-08	1.121338e-05
# #      20000	7.594522e-13	1.528830e-08	1.484299e-05
# #      22000	7.594520e-13	1.680721e-08	1.909587e-05
# #      24000	7.594518e-13	1.832611e-08	2.399395e-05
# #      26000	7.594516e-13	1.984501e-08	2.955614e-05
# #      28000	7.594514e-13	2.136392e-08	3.580107e-05
# #      30000	7.594512e-13	2.288282e-08	4.274961e-05
# #      32000	7.594510e-13	2.440172e-08	5.042686e-05
# #      34000	7.594508e-13	2.592062e-08	5.886336e-05
# #      36000	7.594507e-13	2.743952e-08	6.809563e-05
# #      38000	7.594505e-13	2.895843e-08	7.816570e-05
# #      40000	7.594503e-13	3.047733e-08	8.912000e-05
# #      42000	7.594501e-13	3.199623e-08	1.010077e-04
# #      44000	7.594499e-13	3.351513e-08	1.138787e-04
# #      46000	7.594497e-13	3.503403e-08	1.276226e-04
# #      48000	7.594495e-13	3.655293e-08	1.418661e-04
# #      50000	7.594493e-13	3.807182e-08	1.569704e-04
# #      52000	7.594492e-13	3.959072e-08	1.729590e-04
# #      54000	7.594490e-13	4.110962e-08	1.898574e-04
# #      56000	7.594488e-13	4.262852e-08	2.076935e-04
# #      58000	7.594486e-13	4.414742e-08	2.264971e-04
# #      60000	7.594484e-13	4.566631e-08	2.462997e-04
# #      62000	7.594482e-13	4.718521e-08	2.671339e-04
# #      64000	7.594480e-13	4.870411e-08	2.890336e-04
# #      66000	7.594479e-13	5.022300e-08	3.120328e-04
# #      68000	7.594477e-13	5.174190e-08	3.361659e-04
# #      70000	7.594475e-13	5.326079e-08	3.614666e-04
# #      72000	7.594473e-13	5.477969e-08	3.879677e-04
# #      74000	7.594471e-13	5.629858e-08	4.157009e-04
# #      76000	7.594470e-13	5.781748e-08	4.446958e-04
# #      78000	7.594468e-13	5.933637e-08	4.749803e-04
# #      80000	7.594466e-13	6.085526e-08	5.065800e-04
# #      82000	7.594464e-13	6.237416e-08	5.395178e-04
# #      84000	7.594462e-13	6.389305e-08	5.701150e-04
# #      86000	7.594461e-13	6.541194e-08	5.998268e-04
# #      88000	7.594459e-13	6.693083e-08	6.299789e-04
# #      90000	7.594457e-13	6.844973e-08	6.607939e-04
# #      92000	7.594456e-13	6.996862e-08	6.923756e-04
# #      94000	7.594454e-13	7.148751e-08	7.252062e-04
# #      96000	7.594452e-13	7.300640e-08	7.593578e-04
# #      98000	7.594451e-13	7.452529e-08	7.952651e-04
# #     100000	7.594449e-13	7.604418e-08	8.330774e-04
#
# No convergence within  100000 steps. Stopping criterion: maximum number of iterations reached.
# Output written to: data/2025-07-19_125338_slider_elastic.nc
# Total wall clock time: 0:26:26 (Performance:  63.02 steps/s on 1 x 1 MPI grid)

# %%
from hans.cli.gradientAnalysis import gradientAnalysis
filepath = myProblem.outpath
filename = filepath.split('/')[-1]
gradientAnalysis(filename, r"_plot_output/gA_{}".format(filename))
# Out:
#  /home/qd5728/Integration/hans/hans/cli/gradientAnalysis.py:314: UserWarning:Attempting to set identical low and high ylims makes transformation singular; automatically expanding.

# %%
# plot DH
import numpy as np
from hans.models import pressure
from examples_elasticity.helpers import plot_1D_series

""" C1= 3.5e5
C2= 1.23
Pcav= 0.9e05
P0= 1e05
rho0= 877.7007

rho_arr = np.linspace(800., 880, 500)
pressure_arr = pressure.dowson_higginson(rho_arr, rho0, P0, C1, C2)
pressure_arr[pressure_arr < 90000] = 90000

plot_1D_series(pressure_arr, bShow=True) """
# Out:
# ' C1= 3.5e5\nC2= 1.23\nPcav= 0.9e05\nP0= 1e05\nrho0= 877.7007\n\nrho_arr = np.linspace(800., 880, 500)\npressure_arr = pressure.dowson_higginson(rho_arr, rho0, P0, C1, C2)\npressure_arr[pressure_arr < 90000] = 90000\n\nplot_1D_series(pressure_arr, bShow=True) '
